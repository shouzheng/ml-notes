# %% [markdown]
# # 分类问题

# %% [markdown]
# ## 读入数据

# %%
import numpy as np
import matplotlib.pyplot as plt

# 读入训练数据
train = np.loadtxt('data/images1.csv', delimiter=',', skiprows=1)
train_x = train[:,0:2]
train_y = train[:,2]

# 绘图
plt.plot(train_x[train_y == 1, 0], train_x[train_y == 1, 1], 'o')
plt.plot(train_x[train_y == -1, 0], train_x[train_y == -1, 1], 'x')
plt.axis('scaled')
plt.show()

# %% [markdown]
# ## 感知机的实现

# %% [markdown]
# ### 定义函数

# %%
# 权重初始化
w = np.random.rand(2)

# 判别函数
def f(x):
    if np.dot(w, x) >=0:
        return 1
    else:
        return -1

# %% [markdown]
# ### 训练

# %%
# 重复次数
epoch = 10

# 更新次数
count = 0

# 学习权重
for _ in range(epoch):
    for x, y in zip(train_x, train_y):
        if f(x) != y:
            w = w + y * x
            # 输出日志
            count += 1
            print('第{}次：w = {}'.format(count, w))
# Out:
# 第1次：w = [-152.96978066 -431.53772166]
# 第2次：w = [321.03021934 -47.53772166]
# 第3次：w = [  88.03021934 -477.53772166]
# 第4次：w = [ 484.03021934 -116.53772166]
# 第5次：w = [ 251.03021934 -546.53772166]
# 第6次：w = [ 647.03021934 -185.53772166]
# 第7次：w = [ 248.03021934 -618.53772166]
# 第8次：w = [ 651.03021934 -278.53772166]
# 第9次：w = [ 272.03021934 -694.53772166]
# 第10次：w = [ 535.03021934 -582.53772166]
# 第11次：w = [1032.03021934 -110.53772166]
# 第12次：w = [ 653.03021934 -526.53772166]
# 第13次：w = [ 433.03021934 -788.53772166]
# 第14次：w = [ 907.03021934 -404.53772166]
# 第15次：w = [ 674.03021934 -834.53772166]
# 第16次：w = [1070.03021934 -473.53772166]
# 第17次：w = [ 837.03021934 -903.53772166]
# 第18次：w = [1334.03021934 -431.53772166]
# 第19次：w = [ 955.03021934 -847.53772166]
# 第20次：w = [  556.03021934 -1280.53772166]
# 第21次：w = [ 959.03021934 -940.53772166]

# %% [markdown]
# ### 结果可视化

# %%
x1 = np.arange(0, 500)

plt.plot(train_x[train_y == 1, 0], train_x[train_y == 1, 1], 'o')
plt.plot(train_x[train_y == -1, 0], train_x[train_y == -1, 1], 'x')
plt.plot(x1, -w[0] / w[1] * x1, linestyle='dashed')
plt.show()

# %% [markdown]
# ### 验证

# %%
f([200, 100])

f([100, 200])
# Out:
# -1
