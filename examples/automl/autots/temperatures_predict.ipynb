# %% [markdown]
# 代码来自文章[AutoTS 简洁实现](https://zhuanlan.zhihu.com/p/612771866)
#
# > 我们在这里使用"daily-min-temperatures" 数据集，这个数据集记录了从1981到1990年之间每天的温度数据：

# %% [markdown]
# ## 准备数据

# %%
import pandas as pd
from autots import AutoTS

url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv'
df = pd.read_csv(url, header=0, index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %% [markdown]
# ## 模型设置

# %%
model = AutoTS(
    forecast_length=30,
    frequency='D',
    prediction_interval=0.9,
    ensemble='superensemble', # auto
    max_generations=4,
    num_validations=2,
    validation_method='backwards',
    model_list='superfast',
    transformer_list='superfast',
)

model.fit(df)
# Out:
# Data frequency is: D, used frequency is: D
# Model Number: 1 with model AverageValueNaive in generation 0 of 4
# Model Number: 2 with model AverageValueNaive in generation 0 of 4
# Model Number: 3 with model AverageValueNaive in generation 0 of 4
# Model Number: 4 with model GLS in generation 0 of 4
# Model Number: 5 with model GLS in generation 0 of 4
# Model Number: 6 with model LastValueNaive in generation 0 of 4
# Model Number: 7 with model LastValueNaive in generation 0 of 4
# Model Number: 8 with model LastValueNaive in generation 0 of 4
# Model Number: 9 with model LastValueNaive in generation 0 of 4
# Model Number: 10 with model SeasonalNaive in generation 0 of 4
# Model Number: 11 with model SeasonalNaive in generation 0 of 4
# Model Number: 12 with model SeasonalNaive in generation 0 of 4
# Model Number: 13 with model ConstantNaive in generation 0 of 4
# Model Number: 14 with model SeasonalNaive in generation 0 of 4
# Model Number: 15 with model SeasonalNaive in generation 0 of 4
# Model Number: 16 with model SeasonalityMotif in generation 0 of 4
# Model Number: 17 with model ConstantNaive in generation 0 of 4
# Model Number: 18 with model LastValueNaive in generation 0 of 4
# Model Number: 19 with model AverageValueNaive in generation 0 of 4
# Model Number: 20 with model GLS in generation 0 of 4
# Model Number: 21 with model SeasonalNaive in generation 0 of 4
# Model Number: 22 with model SeasonalityMotif in generation 0 of 4
# Model Number: 23 with model LastValueNaive in generation 0 of 4
# Model Number: 24 with model AverageValueNaive in generation 0 of 4
# Model Number: 25 with model SeasonalNaive in generation 0 of 4
# Model Number: 26 with model SeasonalityMotif in generation 0 of 4
# Model Number: 27 with model SeasonalityMotif in generation 0 of 4
# Model Number: 28 with model AverageValueNaive in generation 0 of 4
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 28 in generation 0: AverageValueNaive
# Model Number: 29 with model ConstantNaive in generation 0 of 4
# Model Number: 30 with model LastValueNaive in generation 0 of 4
# Model Number: 31 with model ConstantNaive in generation 0 of 4
# Model Number: 32 with model LastValueNaive in generation 0 of 4
# Model Number: 33 with model LastValueNaive in generation 0 of 4
# c:\Users\lijinlong9\.conda\envs\ml-notes\lib\site-packages\autots\tools\impute.py:243: FutureWarning: DataFrame.interpolate with method=pad is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.interpolate(method=method, order=5).bfill()
# Model Number: 34 with model SeasonalityMotif in generation 0 of 4
# Model Number: 35 with model AverageValueNaive in generation 0 of 4
# Model Number: 36 with model SeasonalNaive in generation 0 of 4
# Model Number: 37 with model AverageValueNaive in generation 0 of 4
# Model Number: 38 with model SeasonalNaive in generation 0 of 4
# Model Number: 39 with model SeasonalityMotif in generation 0 of 4
# Model Number: 40 with model ConstantNaive in generation 0 of 4
# Model Number: 41 with model ConstantNaive in generation 0 of 4
# Model Number: 42 with model GLS in generation 0 of 4
# Model Number: 43 with model ConstantNaive in generation 0 of 4
# Model Number: 44 with model AverageValueNaive in generation 0 of 4
# Model Number: 45 with model SeasonalNaive in generation 0 of 4
# Model Number: 46 with model SeasonalNaive in generation 0 of 4
# New Generation: 1 of 4
# Model Number: 47 with model SeasonalNaive in generation 1 of 4
# Model Number: 48 with model AverageValueNaive in generation 1 of 4
# Model Number: 49 with model SeasonalNaive in generation 1 of 4
# Model Number: 50 with model SeasonalNaive in generation 1 of 4
# Model Number: 51 with model SeasonalityMotif in generation 1 of 4
# Model Number: 52 with model LastValueNaive in generation 1 of 4
# Model Number: 53 with model ConstantNaive in generation 1 of 4
# Model Number: 54 with model LastValueNaive in generation 1 of 4
# Model Number: 55 with model SeasonalNaive in generation 1 of 4
# Model Number: 56 with model LastValueNaive in generation 1 of 4
# Model Number: 57 with model LastValueNaive in generation 1 of 4
# Model Number: 58 with model LastValueNaive in generation 1 of 4
# Model Number: 59 with model AverageValueNaive in generation 1 of 4
# Model Number: 60 with model LastValueNaive in generation 1 of 4
# Model Number: 61 with model SeasonalNaive in generation 1 of 4
# Model Number: 62 with model SeasonalityMotif in generation 1 of 4
# Model Number: 63 with model LastValueNaive in generation 1 of 4
# Model Number: 64 with model SeasonalityMotif in generation 1 of 4
# Model Number: 65 with model SeasonalityMotif in generation 1 of 4
# Model Number: 66 with model SeasonalityMotif in generation 1 of 4
# Model Number: 67 with model LastValueNaive in generation 1 of 4
# Model Number: 68 with model LastValueNaive in generation 1 of 4
# Model Number: 69 with model AverageValueNaive in generation 1 of 4
# Model Number: 70 with model LastValueNaive in generation 1 of 4
# Model Number: 71 with model ConstantNaive in generation 1 of 4
# Model Number: 72 with model SeasonalNaive in generation 1 of 4
# Model Number: 73 with model SeasonalNaive in generation 1 of 4
# Model Number: 74 with model AverageValueNaive in generation 1 of 4
# Model Number: 75 with model GLS in generation 1 of 4
# Model Number: 76 with model GLS in generation 1 of 4
# New Generation: 2 of 4
# Model Number: 77 with model GLS in generation 2 of 4
# Model Number: 78 with model LastValueNaive in generation 2 of 4
# Model Number: 79 with model LastValueNaive in generation 2 of 4
# Model Number: 80 with model SeasonalityMotif in generation 2 of 4
# Model Number: 81 with model AverageValueNaive in generation 2 of 4
# Model Number: 82 with model LastValueNaive in generation 2 of 4
# Model Number: 83 with model LastValueNaive in generation 2 of 4
# Model Number: 84 with model AverageValueNaive in generation 2 of 4
# Model Number: 85 with model ConstantNaive in generation 2 of 4
# Model Number: 86 with model GLS in generation 2 of 4
# c:\Users\lijinlong9\.conda\envs\ml-notes\lib\site-packages\autots\tools\impute.py:243: FutureWarning: DataFrame.interpolate with method=pad is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.interpolate(method=method, order=5).bfill()
# Model Number: 87 with model SeasonalityMotif in generation 2 of 4
# Model Number: 88 with model AverageValueNaive in generation 2 of 4
# Model Number: 89 with model GLS in generation 2 of 4
# Model Number: 90 with model SeasonalNaive in generation 2 of 4
# Model Number: 91 with model SeasonalityMotif in generation 2 of 4
# Model Number: 92 with model SeasonalNaive in generation 2 of 4
# Model Number: 93 with model GLS in generation 2 of 4
# Model Number: 94 with model AverageValueNaive in generation 2 of 4
# Model Number: 95 with model AverageValueNaive in generation 2 of 4
# Model Number: 96 with model SeasonalityMotif in generation 2 of 4
# Model Number: 97 with model SeasonalNaive in generation 2 of 4
# Model Number: 98 with model AverageValueNaive in generation 2 of 4
# Model Number: 99 with model GLS in generation 2 of 4
# Model Number: 100 with model SeasonalityMotif in generation 2 of 4
# Model Number: 101 with model SeasonalityMotif in generation 2 of 4
# Model Number: 102 with model LastValueNaive in generation 2 of 4
# Model Number: 103 with model ConstantNaive in generation 2 of 4
# Model Number: 104 with model LastValueNaive in generation 2 of 4
# Model Number: 105 with model SeasonalNaive in generation 2 of 4
# Model Number: 106 with model SeasonalityMotif in generation 2 of 4
# New Generation: 3 of 4
# Model Number: 107 with model SeasonalNaive in generation 3 of 4
# Model Number: 108 with model SeasonalityMotif in generation 3 of 4
# Model Number: 109 with model SeasonalNaive in generation 3 of 4
# Model Number: 110 with model SeasonalNaive in generation 3 of 4
# Model Number: 111 with model LastValueNaive in generation 3 of 4
# Model Number: 112 with model AverageValueNaive in generation 3 of 4
# Model Number: 113 with model AverageValueNaive in generation 3 of 4
# Model Number: 114 with model SeasonalNaive in generation 3 of 4
# Model Number: 115 with model AverageValueNaive in generation 3 of 4
# Model Number: 116 with model AverageValueNaive in generation 3 of 4
# Model Number: 117 with model AverageValueNaive in generation 3 of 4
# Model Number: 118 with model LastValueNaive in generation 3 of 4
# Model Number: 119 with model GLS in generation 3 of 4
# Model Number: 120 with model AverageValueNaive in generation 3 of 4
# Model Number: 121 with model LastValueNaive in generation 3 of 4
# Model Number: 122 with model AverageValueNaive in generation 3 of 4
# Model Number: 123 with model SeasonalNaive in generation 3 of 4
# Model Number: 124 with model SeasonalNaive in generation 3 of 4
# Model Number: 125 with model LastValueNaive in generation 3 of 4
# Model Number: 126 with model LastValueNaive in generation 3 of 4
# Model Number: 127 with model ConstantNaive in generation 3 of 4
# Model Number: 128 with model GLS in generation 3 of 4
# Model Number: 129 with model SeasonalityMotif in generation 3 of 4
# Model Number: 130 with model GLS in generation 3 of 4
# Model Number: 131 with model SeasonalNaive in generation 3 of 4
# Model Number: 132 with model AverageValueNaive in generation 3 of 4
# Model Number: 133 with model LastValueNaive in generation 3 of 4
# Model Number: 134 with model AverageValueNaive in generation 3 of 4
# Model Number: 135 with model GLS in generation 3 of 4
# Model Number: 136 with model GLS in generation 3 of 4
# New Generation: 4 of 4
# Model Number: 137 with model LastValueNaive in generation 4 of 4
# Model Number: 138 with model AverageValueNaive in generation 4 of 4
# Model Number: 139 with model SeasonalityMotif in generation 4 of 4
# Model Number: 140 with model LastValueNaive in generation 4 of 4
# Model Number: 141 with model SeasonalityMotif in generation 4 of 4
# Model Number: 142 with model AverageValueNaive in generation 4 of 4
# Model Number: 143 with model AverageValueNaive in generation 4 of 4
# Model Number: 144 with model LastValueNaive in generation 4 of 4
# Model Number: 145 with model SeasonalityMotif in generation 4 of 4
# Model Number: 146 with model LastValueNaive in generation 4 of 4
# Model Number: 147 with model SeasonalityMotif in generation 4 of 4
# Model Number: 148 with model SeasonalNaive in generation 4 of 4
# Model Number: 149 with model SeasonalityMotif in generation 4 of 4
# Model Number: 150 with model AverageValueNaive in generation 4 of 4
# Model Number: 151 with model LastValueNaive in generation 4 of 4
# Model Number: 152 with model SeasonalNaive in generation 4 of 4
# Model Number: 153 with model SeasonalNaive in generation 4 of 4
# Model Number: 154 with model AverageValueNaive in generation 4 of 4
# Model Number: 155 with model SeasonalNaive in generation 4 of 4
# Model Number: 156 with model AverageValueNaive in generation 4 of 4
# Model Number: 157 with model GLS in generation 4 of 4
# Model Number: 158 with model LastValueNaive in generation 4 of 4
# Model Number: 159 with model SeasonalNaive in generation 4 of 4
# Model Number: 160 with model LastValueNaive in generation 4 of 4
# Model Number: 161 with model SeasonalityMotif in generation 4 of 4
# Model Number: 162 with model SeasonalNaive in generation 4 of 4
# Model Number: 163 with model AverageValueNaive in generation 4 of 4
# Model Number: 164 with model AverageValueNaive in generation 4 of 4
# Model Number: 165 with model SeasonalityMotif in generation 4 of 4
# Model Number: 166 with model SeasonalNaive in generation 4 of 4
# TotalRuntime missing in 5!
# Validation Round: 1
# Model Number: 1 of 25 with model LastValueNaive for Validation 1
# 📈 1 - LastValueNaive with avg smape 24.49:
# Model Number: 2 of 25 with model LastValueNaive for Validation 1
# 2 - LastValueNaive with avg smape 24.49:
# Model Number: 3 of 25 with model LastValueNaive for Validation 1
# 3 - LastValueNaive with avg smape 24.49:
# Model Number: 4 of 25 with model LastValueNaive for Validation 1
# 4 - LastValueNaive with avg smape 24.49:
# Model Number: 5 of 25 with model LastValueNaive for Validation 1
# 5 - LastValueNaive with avg smape 24.49:
# Model Number: 6 of 25 with model LastValueNaive for Validation 1
# 6 - LastValueNaive with avg smape 24.49:
# Model Number: 7 of 25 with model GLS for Validation 1
# 📈 7 - GLS with avg smape 20.2:
# Model Number: 8 of 25 with model AverageValueNaive for Validation 1
# 8 - AverageValueNaive with avg smape 24.49:
# Model Number: 9 of 25 with model SeasonalityMotif for Validation 1
# 9 - SeasonalityMotif with avg smape 29.34:
# Model Number: 10 of 25 with model AverageValueNaive for Validation 1
# 📈 10 - AverageValueNaive with avg smape 16.21:
# Model Number: 11 of 25 with model AverageValueNaive for Validation 1
# 11 - AverageValueNaive with avg smape 24.47:
# Model Number: 12 of 25 with model SeasonalNaive for Validation 1
# 12 - SeasonalNaive with avg smape 30.03:
# Model Number: 13 of 25 with model SeasonalNaive for Validation 1
# 13 - SeasonalNaive with avg smape 25.91:
# Model Number: 14 of 25 with model SeasonalityMotif for Validation 1
# 14 - SeasonalityMotif with avg smape 43.07:
# Model Number: 15 of 25 with model SeasonalNaive for Validation 1
# 15 - SeasonalNaive with avg smape 30.02:
# Model Number: 16 of 25 with model SeasonalNaive for Validation 1
# 16 - SeasonalNaive with avg smape 30.02:
# Model Number: 17 of 25 with model SeasonalNaive for Validation 1
# 17 - SeasonalNaive with avg smape 30.02:
# Model Number: 18 of 25 with model SeasonalNaive for Validation 1
# 18 - SeasonalNaive with avg smape 29.21:
# Model Number: 19 of 25 with model GLS for Validation 1
# 19 - GLS with avg smape 18.96:
# Model Number: 20 of 25 with model AverageValueNaive for Validation 1
# 20 - AverageValueNaive with avg smape 23.81:
# Model Number: 21 of 25 with model SeasonalityMotif for Validation 1
# 21 - SeasonalityMotif with avg smape 22.36:
# Model Number: 22 of 25 with model GLS for Validation 1
# 22 - GLS with avg smape 24.47:
# Model Number: 23 of 25 with model AverageValueNaive for Validation 1
# 📈 23 - AverageValueNaive with avg smape 15.93:
# Model Number: 24 of 25 with model AverageValueNaive for Validation 1
# 24 - AverageValueNaive with avg smape 21.96:
# Model Number: 25 of 25 with model SeasonalityMotif for Validation 1
# 25 - SeasonalityMotif with avg smape 32.58:
# Validation Round: 2
# Model Number: 1 of 25 with model LastValueNaive for Validation 2
# 📈 1 - LastValueNaive with avg smape 21.28:
# Model Number: 2 of 25 with model LastValueNaive for Validation 2
# 2 - LastValueNaive with avg smape 21.28:
# Model Number: 3 of 25 with model LastValueNaive for Validation 2
# 3 - LastValueNaive with avg smape 21.28:
# Model Number: 4 of 25 with model LastValueNaive for Validation 2
# 4 - LastValueNaive with avg smape 21.28:
# Model Number: 5 of 25 with model LastValueNaive for Validation 2
# 5 - LastValueNaive with avg smape 21.28:
# Model Number: 6 of 25 with model LastValueNaive for Validation 2
# 6 - LastValueNaive with avg smape 21.28:
# Model Number: 7 of 25 with model GLS for Validation 2
# 7 - GLS with avg smape 24.19:
# Model Number: 8 of 25 with model AverageValueNaive for Validation 2
# 8 - AverageValueNaive with avg smape 21.28:
# Model Number: 9 of 25 with model SeasonalityMotif for Validation 2
# 9 - SeasonalityMotif with avg smape 27.94:
# Model Number: 10 of 25 with model AverageValueNaive for Validation 2
# 10 - AverageValueNaive with avg smape 24.89:
# Model Number: 11 of 25 with model AverageValueNaive for Validation 2
# 📈 11 - AverageValueNaive with avg smape 21.17:
# Model Number: 12 of 25 with model SeasonalNaive for Validation 2
# 📈 12 - SeasonalNaive with avg smape 18.94:
# Model Number: 13 of 25 with model SeasonalNaive for Validation 2
# 📈 13 - SeasonalNaive with avg smape 18.73:
# Model Number: 14 of 25 with model SeasonalityMotif for Validation 2
# 14 - SeasonalityMotif with avg smape 31.82:
# Model Number: 15 of 25 with model SeasonalNaive for Validation 2
# 15 - SeasonalNaive with avg smape 18.94:
# Model Number: 16 of 25 with model SeasonalNaive for Validation 2
# 16 - SeasonalNaive with avg smape 18.94:
# Model Number: 17 of 25 with model SeasonalNaive for Validation 2
# 17 - SeasonalNaive with avg smape 18.94:
# Model Number: 18 of 25 with model SeasonalNaive for Validation 2
# 18 - SeasonalNaive with avg smape 22.41:
# Model Number: 19 of 25 with model GLS for Validation 2
# 19 - GLS with avg smape 27.34:
# Model Number: 20 of 25 with model AverageValueNaive for Validation 2
# 20 - AverageValueNaive with avg smape 22.06:
# Model Number: 21 of 25 with model SeasonalityMotif for Validation 2
# 📈 21 - SeasonalityMotif with avg smape 18.57:
# Model Number: 22 of 25 with model GLS for Validation 2
# 22 - GLS with avg smape 21.17:
# Model Number: 23 of 25 with model AverageValueNaive for Validation 2
# 23 - AverageValueNaive with avg smape 23.36:
# Model Number: 24 of 25 with model AverageValueNaive for Validation 2
# 24 - AverageValueNaive with avg smape 23.81:
# Model Number: 25 of 25 with model SeasonalityMotif for Validation 2
# 📈 25 - SeasonalityMotif with avg smape 17.93:
# TotalRuntime missing in 6!
# Validation Round: 1
# TotalRuntime missing in 0!
# Validation Round: 2
# TotalRuntime missing in 0!
# Initiated AutoTS object with best model:
# AverageValueNaive
# {'fillna': 'ffill', 'transformations': {'0': 'AlignLastValue', '1': 'RobustScaler', '2': 'ClipOutliers', '3': 'ClipOutliers'}, 'transformation_params': {'0': {'rows': 1, 'lag': 7, 'method': 'additive', 'strength': 1.0, 'first_value_only': False}, '1': {}, '2': {'method': 'clip', 'std_threshold': 4, 'fillna': None}, '3': {'method': 'clip', 'std_threshold': 3, 'fillna': None}}}
# {'method': 'Weighted_Mean', 'window': None}
# Validation: 0, 1, 2
# SMAPE: 13.8397304209707, 15.928862010883744, 23.359835646968516
# MAE: 2.01, 2.0000000000000004, 2.6166666666666663
# SPL: 0.4552158960641956, 0.43860759493670887, 0.5275204359673021

# %% [markdown]
# ## 查看模型预测结果

# %%
# 查看预测结果
preds = model.predict()
preds.forecast.head()
# Out:
#             Temp
# 1991-01-01  12.9
# 1991-01-02  12.9
# 1991-01-03  12.9
# 1991-01-04  12.9
# 1991-01-05  12.9

# %%
# plot a sample
preds.plot(model.df_wide_numeric,
           series=model.df_wide_numeric.columns[0],
           start_date="1990-12-01")
# Out:
# <Axes: title={'center': 'Temp with model AverageValueNaive'}>

# %% [markdown]
# ## 查看模型结果

# %%
# Print the details of the best model
# ? 最好模型评定逻辑？
print(model.best_model) # print(model) etc.
# Out:
#                                    ID              Model  \
# 123  c1324f6f63f79201cb09d09bb955c54e  AverageValueNaive
#
#                                  ModelParameters  \
# 123  {"method": "Weighted_Mean", "window": null}
#
#                               TransformationParameters  Ensemble
# 123  {"fillna": "ffill", "transformations": {"0": "...         0

# %%
model_results_df = model.results()
model_results_df[model_results_df['ID']=='c1324f6f63f79201cb09d09bb955c54e']
# Out:
#                                    ID              Model  \
# 153  c1324f6f63f79201cb09d09bb955c54e  AverageValueNaive
# 188  c1324f6f63f79201cb09d09bb955c54e  AverageValueNaive
# 213  c1324f6f63f79201cb09d09bb955c54e  AverageValueNaive
#
#                                  ModelParameters  \
# 153  {"method": "Weighted_Mean", "window": null}
# 188  {"method": "Weighted_Mean", "window": null}
# 213  {"method": "Weighted_Mean", "window": null}
#
#                               TransformationParameters  TransformationRuntime  \
# 153  {"fillna": "ffill", "transformations": {"0": "... 0 days 00:00:00.017957
# 188  {"fillna": "ffill", "transformations": {"0": "... 0 days 00:00:00.023902
# 213  {"fillna": "ffill", "transformations": {"0": "... 0 days 00:00:00.019949
#
#     FitRuntime         PredictRuntime           TotalRuntime  Ensemble  \
# 153     0 days 0 days 00:00:00.000988 0 days 00:00:00.024899         0
# 188     0 days 0 days 00:00:00.001995 0 days 00:00:00.036901         0
# 213     0 days 0 days 00:00:00.000996 0 days 00:00:00.027924         0
#
#     Exceptions  ...  oda_weighted  dwae_weighted  mqae_weighted  \
# 153        NaN  ...      0.333333       2.055412          1.228
# 188        NaN  ...      0.900000       1.609474          1.396
# 213        NaN  ...      0.366667       2.456313          1.928
#
#     ewmae_weighted  uwmse_weighted  smoothness_weighted  wasserstein_weighted  \
# 153       5.733933        3.109717             0.010292             11.360222
# 188       7.054604        3.619975             0.069912              4.039367
# 213      13.680589        7.566172             0.023851              5.855177
#
#      dwd_weighted  TotalRuntimeSeconds      Score
# 153      9.660413               0.0249  17.542036
# 188     14.380759               0.0369  18.179020
# 213     16.348638               0.0279  23.604486
#
# [3 rows x 60 columns]

# %%
# 查看模型结果
print(model.results().shape)
model.results().sort_values(by="Score", ascending=False).head()
# Out:
# (216, 60)
#                                    ID             Model  \
# 75   2bdd614fbb85cd22e8683a4f27fb6bf6               GLS
# 154  efa204c1bfd04a844ee4229b1f066b10     SeasonalNaive
# 156  f7c5c94e24c643c45dd0e2c1b96a055f               GLS
# 30   e78ae1f747ce4f2163b5837ed0388ff7     ConstantNaive
# 33   188df9cdd57284c3d16962cfdd76da5c  SeasonalityMotif
#
#                                        ModelParameters  \
# 75                                                  {}
# 154    {"method": "lastvalue", "lag_1": 2, "lag_2": 1}
# 156                                                 {}
# 30                                    {"constant": -1}
# 33   {"window": 7, "point_method": "closest", "dist...
#
#                               TransformationParameters  TransformationRuntime  \
# 75   {"fillna": "pchip", "transformations": {"0": "... 0 days 00:00:00.014958
# 154  {"fillna": "rolling_mean", "transformations": ... 0 days 00:00:00.011969
# 156  {"fillna": "rolling_mean", "transformations": ... 0 days 00:00:00.026928
# 30   {"fillna": "ffill", "transformations": {"0": "... 0 days 00:00:00.021941
# 33   {"fillna": "mean", "transformations": {"0": "D... 0 days 00:00:00.033876
#
#                 FitRuntime         PredictRuntime           TotalRuntime  \
# 75  0 days 00:00:00.001996 0 days 00:00:00.067820 0 days 00:00:00.089760
# 154        0 days 00:00:00 0 days 00:00:00.069812 0 days 00:00:00.086768
# 156 0 days 00:00:00.001994 0 days 00:00:00.068816 0 days 00:00:00.102726
# 30         0 days 00:00:00        0 days 00:00:00 0 days 00:00:00.026928
# 33         0 days 00:00:00 0 days 00:00:00.032946 0 days 00:00:00.072806
#
#      Ensemble Exceptions  ...  oda_weighted  dwae_weighted  mqae_weighted  \
# 75          0        NaN  ...      0.400000       1.948967       1.625739
# 154         0        NaN  ...      0.666667      82.385815     162.355923
# 156         0        NaN  ...      0.433333       4.781605       4.306405
# 30          0        NaN  ...      0.333333      24.853902      36.787596
# 33          0        NaN  ...      0.666667      17.524700      45.005131
#
#     ewmae_weighted  uwmse_weighted  smoothness_weighted  wasserstein_weighted  \
# 75        8.108989        3.447718             0.087394             12.436204
# 154    1043.252426    28353.121161             0.868546            776.888941
# 156      16.336717       70.682918             0.365510             47.107573
# 30      229.895192     1360.519918             0.000000            180.856760
# 33      185.399349     1569.287769             1.873881            264.368245
#
#      dwd_weighted  TotalRuntimeSeconds          Score
# 75       9.296666               0.0898  311267.056207
# 154     64.030007               0.0868    1020.761414
# 156      3.316859               0.1027     903.246900
# 30       6.286356               0.0269     333.063493
# 33      20.543328               0.0728     317.407261
#
# [5 rows x 60 columns]

# %%
# 查看模型在验证集的结果？
print(model.results("validation").shape)
model.results("validation").sort_values(by="Score", ascending=False).head()
# Out:
# (165, 54)
#                                    ID             Model  \
# 32   2bdd614fbb85cd22e8683a4f27fb6bf6               GLS
# 145  efa204c1bfd04a844ee4229b1f066b10     SeasonalNaive
# 157  f7c5c94e24c643c45dd0e2c1b96a055f               GLS
# 140  e78ae1f747ce4f2163b5837ed0388ff7     ConstantNaive
# 15   188df9cdd57284c3d16962cfdd76da5c  SeasonalityMotif
#
#                                        ModelParameters  \
# 32                                                  {}
# 145    {"method": "lastvalue", "lag_1": 2, "lag_2": 1}
# 157                                                 {}
# 140                                   {"constant": -1}
# 15   {"window": 7, "point_method": "closest", "dist...
#
#                               TransformationParameters  Ensemble  Runs  \
# 32   {"fillna": "pchip", "transformations": {"0": "...         0     1
# 145  {"fillna": "rolling_mean", "transformations": ...         0     1
# 157  {"fillna": "rolling_mean", "transformations": ...         0     1
# 140  {"fillna": "ffill", "transformations": {"0": "...         0     1
# 15   {"fillna": "mean", "transformations": {"0": "D...         0     1
#
#           smape         mae        rmse      made  ...  wasserstein_weighted  \
# 32    16.408797    2.330680    2.975429  0.605463  ...             12.436204
# 145  160.633781  193.979120  223.062316  4.773441  ...            776.888941
# 157   58.062180    6.225337    8.033373  0.790879  ...             47.107573
# 140  185.332194   43.544237   49.179867  1.099768  ...            180.856760
# 15   123.171286   45.946851   46.085972  1.752807  ...            264.368245
#
#      dwd_weighted  containment_weighted  contour_weighted  \
# 32       9.296666              1.000000          0.666667
# 145     64.030007              0.000000          0.533333
# 157      3.316859              0.966667          0.566667
# 140      6.286356              0.000000          0.466667
# 15      20.543328              0.000000          0.400000
#
#      TotalRuntimeSeconds          Score  lowest_series_mape  \
# 32                0.0898  311267.056207           20.851063
# 145               0.0868    1020.761414         1735.403461
# 157               0.1027     903.246900           55.693991
# 140               0.0269     333.063493          389.561615
# 15                0.0728     317.407261          411.056220
#
#      lowest_series_mape_name  highest_series_mape  highest_series_mape_name
# 32                      Temp            20.851063                      Temp
# 145                     Temp          1735.403461                      Temp
# 157                     Temp            55.693991                      Temp
# 140                     Temp           389.561615                      Temp
# 15                      Temp           411.056220                      Temp
#
# [5 rows x 54 columns]
