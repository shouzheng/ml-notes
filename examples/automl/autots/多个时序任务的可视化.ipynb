# %%
from autots import AutoTS, load_daily

df = load_daily(long=False)  # long or non-numeric data won't work with this function

# %%
import matplotlib.pyplot as plt

model = AutoTS(model_list="superfast", transformer_list="superfast").fit(df)
prediction = model.predict()

prediction.plot(
    model.df_wide_numeric,
    series=model.df_wide_numeric.columns[2],
    remove_zeroes=False,
    start_date="2018-09-26",
)
plt.show()

model.plot_per_series_mape(kind="pie")
plt.show()

model.plot_per_series_error()
plt.show()

model.plot_generation_loss()
plt.show()

if model.best_model_ensemble == 2:
    model.plot_horizontal_per_generation()
    plt.show()
    model.plot_horizontal_transformers(method="fillna")
    plt.show()
    model.plot_horizontal_transformers()
    plt.show()
    model.plot_horizontal()
    plt.show()
    if "mosaic" in model.best_model["ModelParameters"].iloc[0].lower():
        mosaic_df = model.mosaic_to_df()
        print(mosaic_df[mosaic_df.columns[0:5]].head(5))

if False:  # slow
    model.plot_backforecast(n_splits="auto", start_date="2019-01-01")
# Out:
# Data frequency is: D, used frequency is: D
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model GLS in generation 0 of 10
# Model Number: 5 with model GLS in generation 0 of 10
# Model Number: 6 with model LastValueNaive in generation 0 of 10
# Model Number: 7 with model LastValueNaive in generation 0 of 10
# Model Number: 8 with model LastValueNaive in generation 0 of 10
# Model Number: 9 with model LastValueNaive in generation 0 of 10
# Model Number: 10 with model SeasonalNaive in generation 0 of 10
# Model Number: 11 with model SeasonalNaive in generation 0 of 10
# Model Number: 12 with model SeasonalNaive in generation 0 of 10
# Model Number: 13 with model ConstantNaive in generation 0 of 10
# Model Number: 14 with model SeasonalNaive in generation 0 of 10
# Model Number: 15 with model SeasonalNaive in generation 0 of 10
# Model Number: 16 with model SeasonalityMotif in generation 0 of 10
# Model Number: 17 with model ConstantNaive in generation 0 of 10
# Model Number: 18 with model LastValueNaive in generation 0 of 10
# Model Number: 19 with model AverageValueNaive in generation 0 of 10
# Model Number: 20 with model GLS in generation 0 of 10
# Model Number: 21 with model SeasonalNaive in generation 0 of 10
# Model Number: 22 with model SeasonalityMotif in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model AverageValueNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalityMotif in generation 0 of 10
# Model Number: 27 with model SeasonalityMotif in generation 0 of 10
# Model Number: 28 with model AverageValueNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 28 in generation 0: AverageValueNaive
# Model Number: 29 with model ConstantNaive in generation 0 of 10
# Model Number: 30 with model LastValueNaive in generation 0 of 10
# Model Number: 31 with model ConstantNaive in generation 0 of 10
# Model Number: 32 with model LastValueNaive in generation 0 of 10
# Model Number: 33 with model LastValueNaive in generation 0 of 10
# Model Number: 34 with model SeasonalityMotif in generation 0 of 10
# Model Number: 35 with model AverageValueNaive in generation 0 of 10
# Model Number: 36 with model SeasonalNaive in generation 0 of 10
# Model Number: 37 with model AverageValueNaive in generation 0 of 10
# Model Number: 38 with model SeasonalNaive in generation 0 of 10
# Model Number: 39 with model SeasonalityMotif in generation 0 of 10
# Model Number: 40 with model ConstantNaive in generation 0 of 10
# Model Number: 41 with model ConstantNaive in generation 0 of 10
# Model Number: 42 with model GLS in generation 0 of 10
# Model Number: 43 with model ConstantNaive in generation 0 of 10
# Model Number: 44 with model AverageValueNaive in generation 0 of 10
# Model Number: 45 with model SeasonalNaive in generation 0 of 10
# Model Number: 46 with model SeasonalNaive in generation 0 of 10
# New Generation: 1 of 10
# Model Number: 47 with model ConstantNaive in generation 1 of 10
# Model Number: 48 with model SeasonalityMotif in generation 1 of 10
# Model Number: 49 with model LastValueNaive in generation 1 of 10
# Model Number: 50 with model AverageValueNaive in generation 1 of 10
# Model Number: 51 with model AverageValueNaive in generation 1 of 10
# Model Number: 52 with model AverageValueNaive in generation 1 of 10
# Model Number: 53 with model LastValueNaive in generation 1 of 10
# Model Number: 54 with model SeasonalNaive in generation 1 of 10
# Model Number: 55 with model SeasonalNaive in generation 1 of 10
# Model Number: 56 with model ConstantNaive in generation 1 of 10
# Model Number: 57 with model SeasonalNaive in generation 1 of 10
# Model Number: 58 with model SeasonalNaive in generation 1 of 10
# Model Number: 59 with model LastValueNaive in generation 1 of 10
# Model Number: 60 with model SeasonalityMotif in generation 1 of 10
# Model Number: 61 with model ConstantNaive in generation 1 of 10
# Model Number: 62 with model GLS in generation 1 of 10
# Model Number: 63 with model AverageValueNaive in generation 1 of 10
# Model Number: 64 with model SeasonalityMotif in generation 1 of 10
# Model Number: 65 with model AverageValueNaive in generation 1 of 10
# Model Number: 66 with model SeasonalityMotif in generation 1 of 10
# Model Number: 67 with model SeasonalNaive in generation 1 of 10
# Model Number: 68 with model LastValueNaive in generation 1 of 10
# Model Number: 69 with model ConstantNaive in generation 1 of 10
# Model Number: 70 with model ConstantNaive in generation 1 of 10
# Model Number: 71 with model AverageValueNaive in generation 1 of 10
# Model Number: 72 with model LastValueNaive in generation 1 of 10
# Model Number: 73 with model GLS in generation 1 of 10
# Model Number: 74 with model ConstantNaive in generation 1 of 10
# Model Number: 75 with model SeasonalNaive in generation 1 of 10
# Model Number: 76 with model SeasonalityMotif in generation 1 of 10
# New Generation: 2 of 10
# Model Number: 77 with model AverageValueNaive in generation 2 of 10
# Model Number: 78 with model LastValueNaive in generation 2 of 10
# Model Number: 79 with model GLS in generation 2 of 10
# Model Number: 80 with model ConstantNaive in generation 2 of 10
# Model Number: 81 with model LastValueNaive in generation 2 of 10
# Model Number: 82 with model SeasonalityMotif in generation 2 of 10
# Model Number: 83 with model AverageValueNaive in generation 2 of 10
# Model Number: 84 with model AverageValueNaive in generation 2 of 10
# Model Number: 85 with model GLS in generation 2 of 10
# Model Number: 86 with model LastValueNaive in generation 2 of 10
# Model Number: 87 with model ConstantNaive in generation 2 of 10
# Model Number: 88 with model LastValueNaive in generation 2 of 10
# Model Number: 89 with model AverageValueNaive in generation 2 of 10
# Model Number: 90 with model LastValueNaive in generation 2 of 10
# Model Number: 91 with model AverageValueNaive in generation 2 of 10
# Model Number: 92 with model ConstantNaive in generation 2 of 10
# Model Number: 93 with model SeasonalityMotif in generation 2 of 10
# Model Number: 94 with model ConstantNaive in generation 2 of 10
# Model Number: 95 with model LastValueNaive in generation 2 of 10
# Model Number: 96 with model ConstantNaive in generation 2 of 10
# Model Number: 97 with model LastValueNaive in generation 2 of 10
# Model Number: 98 with model LastValueNaive in generation 2 of 10
# Model Number: 99 with model LastValueNaive in generation 2 of 10
# Model Number: 100 with model ConstantNaive in generation 2 of 10
# Model Number: 101 with model SeasonalityMotif in generation 2 of 10
# Model Number: 102 with model LastValueNaive in generation 2 of 10
# Model Number: 103 with model AverageValueNaive in generation 2 of 10
# Model Number: 104 with model SeasonalityMotif in generation 2 of 10
# Model Number: 105 with model SeasonalNaive in generation 2 of 10
# Model Number: 106 with model SeasonalNaive in generation 2 of 10
# New Generation: 3 of 10
# Model Number: 107 with model LastValueNaive in generation 3 of 10
# Model Number: 108 with model ConstantNaive in generation 3 of 10
# Model Number: 109 with model AverageValueNaive in generation 3 of 10
# Model Number: 110 with model LastValueNaive in generation 3 of 10
# Model Number: 111 with model SeasonalNaive in generation 3 of 10
# Model Number: 112 with model ConstantNaive in generation 3 of 10
# Model Number: 113 with model LastValueNaive in generation 3 of 10
# Model Number: 114 with model SeasonalityMotif in generation 3 of 10
# Model Number: 115 with model AverageValueNaive in generation 3 of 10
# Model Number: 116 with model SeasonalityMotif in generation 3 of 10
# Model Number: 117 with model AverageValueNaive in generation 3 of 10
# Model Number: 118 with model AverageValueNaive in generation 3 of 10
# Model Number: 119 with model GLS in generation 3 of 10
# Model Number: 120 with model ConstantNaive in generation 3 of 10
# Model Number: 121 with model AverageValueNaive in generation 3 of 10
# Model Number: 122 with model SeasonalNaive in generation 3 of 10
# Model Number: 123 with model GLS in generation 3 of 10
# Model Number: 124 with model ConstantNaive in generation 3 of 10
# Model Number: 125 with model AverageValueNaive in generation 3 of 10
# Model Number: 126 with model LastValueNaive in generation 3 of 10
# Model Number: 127 with model GLS in generation 3 of 10
# Model Number: 128 with model GLS in generation 3 of 10
# Model Number: 129 with model LastValueNaive in generation 3 of 10
# Model Number: 130 with model SeasonalityMotif in generation 3 of 10
# Model Number: 131 with model SeasonalNaive in generation 3 of 10
# Model Number: 132 with model ConstantNaive in generation 3 of 10
# Model Number: 133 with model ConstantNaive in generation 3 of 10
# Model Number: 134 with model SeasonalNaive in generation 3 of 10
# Model Number: 135 with model SeasonalityMotif in generation 3 of 10
# Model Number: 136 with model AverageValueNaive in generation 3 of 10
# New Generation: 4 of 10
# Model Number: 137 with model ConstantNaive in generation 4 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 137 in generation 4: ConstantNaive
# Model Number: 138 with model ConstantNaive in generation 4 of 10
# Model Number: 139 with model AverageValueNaive in generation 4 of 10
# Model Number: 140 with model SeasonalNaive in generation 4 of 10
# Model Number: 141 with model AverageValueNaive in generation 4 of 10
# Model Number: 142 with model SeasonalityMotif in generation 4 of 10
# Model Number: 143 with model GLS in generation 4 of 10
# Model Number: 144 with model LastValueNaive in generation 4 of 10
# Model Number: 145 with model AverageValueNaive in generation 4 of 10
# Model Number: 146 with model LastValueNaive in generation 4 of 10
# Model Number: 147 with model LastValueNaive in generation 4 of 10
# Model Number: 148 with model ConstantNaive in generation 4 of 10
# Model Number: 149 with model AverageValueNaive in generation 4 of 10
# Model Number: 150 with model LastValueNaive in generation 4 of 10
# Model Number: 151 with model LastValueNaive in generation 4 of 10
# Model Number: 152 with model SeasonalityMotif in generation 4 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 152 in generation 4: SeasonalityMotif
# Model Number: 153 with model LastValueNaive in generation 4 of 10
# Model Number: 154 with model SeasonalNaive in generation 4 of 10
# Model Number: 155 with model LastValueNaive in generation 4 of 10
# Model Number: 156 with model LastValueNaive in generation 4 of 10
# Model Number: 157 with model ConstantNaive in generation 4 of 10
# Model Number: 158 with model AverageValueNaive in generation 4 of 10
# Model Number: 159 with model LastValueNaive in generation 4 of 10
# Model Number: 160 with model AverageValueNaive in generation 4 of 10
# Model Number: 161 with model SeasonalityMotif in generation 4 of 10
# Model Number: 162 with model SeasonalNaive in generation 4 of 10
# Model Number: 163 with model SeasonalNaive in generation 4 of 10
# Model Number: 164 with model AverageValueNaive in generation 4 of 10
# Model Number: 165 with model LastValueNaive in generation 4 of 10
# Model Number: 166 with model SeasonalityMotif in generation 4 of 10
# New Generation: 5 of 10
# Model Number: 167 with model ConstantNaive in generation 5 of 10
# Model Number: 168 with model AverageValueNaive in generation 5 of 10
# Model Number: 169 with model AverageValueNaive in generation 5 of 10
# Model Number: 170 with model AverageValueNaive in generation 5 of 10
# Model Number: 171 with model AverageValueNaive in generation 5 of 10
# Model Number: 172 with model ConstantNaive in generation 5 of 10
# Model Number: 173 with model LastValueNaive in generation 5 of 10
# Model Number: 174 with model AverageValueNaive in generation 5 of 10
# Model Number: 175 with model ConstantNaive in generation 5 of 10
# Model Number: 176 with model GLS in generation 5 of 10
# Model Number: 177 with model LastValueNaive in generation 5 of 10
# Model Number: 178 with model AverageValueNaive in generation 5 of 10
# Model Number: 179 with model ConstantNaive in generation 5 of 10
# Model Number: 180 with model SeasonalityMotif in generation 5 of 10
# Model Number: 181 with model SeasonalNaive in generation 5 of 10
# Model Number: 182 with model LastValueNaive in generation 5 of 10
# Model Number: 183 with model SeasonalityMotif in generation 5 of 10
# Model Number: 184 with model LastValueNaive in generation 5 of 10
# Model Number: 185 with model LastValueNaive in generation 5 of 10
# Model Number: 186 with model AverageValueNaive in generation 5 of 10
# Model Number: 187 with model SeasonalityMotif in generation 5 of 10
# Model Number: 188 with model LastValueNaive in generation 5 of 10
# Model Number: 189 with model LastValueNaive in generation 5 of 10
# Model Number: 190 with model LastValueNaive in generation 5 of 10
# New Generation: 6 of 10
# Model Number: 191 with model AverageValueNaive in generation 6 of 10
# Model Number: 192 with model AverageValueNaive in generation 6 of 10
# Model Number: 193 with model AverageValueNaive in generation 6 of 10
# Model Number: 194 with model LastValueNaive in generation 6 of 10
# Model Number: 195 with model SeasonalityMotif in generation 6 of 10
# Model Number: 196 with model AverageValueNaive in generation 6 of 10
# Model Number: 197 with model AverageValueNaive in generation 6 of 10
# Model Number: 198 with model AverageValueNaive in generation 6 of 10
# Model Number: 199 with model ConstantNaive in generation 6 of 10
# Model Number: 200 with model LastValueNaive in generation 6 of 10
# Model Number: 201 with model SeasonalityMotif in generation 6 of 10
# Model Number: 202 with model ConstantNaive in generation 6 of 10
# Model Number: 203 with model SeasonalityMotif in generation 6 of 10
# Model Number: 204 with model ConstantNaive in generation 6 of 10
# Model Number: 205 with model SeasonalityMotif in generation 6 of 10
# Model Number: 206 with model AverageValueNaive in generation 6 of 10
# Model Number: 207 with model SeasonalityMotif in generation 6 of 10
# Model Number: 208 with model AverageValueNaive in generation 6 of 10
# Model Number: 209 with model AverageValueNaive in generation 6 of 10
# Model Number: 210 with model LastValueNaive in generation 6 of 10
# Model Number: 211 with model ConstantNaive in generation 6 of 10
# Model Number: 212 with model LastValueNaive in generation 6 of 10
# Model Number: 213 with model LastValueNaive in generation 6 of 10
# Model Number: 214 with model SeasonalNaive in generation 6 of 10
# New Generation: 7 of 10
# Model Number: 215 with model SeasonalityMotif in generation 7 of 10
# Model Number: 216 with model SeasonalityMotif in generation 7 of 10
# Model Number: 217 with model AverageValueNaive in generation 7 of 10
# Model Number: 218 with model AverageValueNaive in generation 7 of 10
# Model Number: 219 with model LastValueNaive in generation 7 of 10
# Model Number: 220 with model LastValueNaive in generation 7 of 10
# Model Number: 221 with model AverageValueNaive in generation 7 of 10
# Model Number: 222 with model LastValueNaive in generation 7 of 10
# Model Number: 223 with model LastValueNaive in generation 7 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 223 in generation 7: LastValueNaive
# Model Number: 224 with model ConstantNaive in generation 7 of 10
# Model Number: 225 with model SeasonalityMotif in generation 7 of 10
# Model Number: 226 with model LastValueNaive in generation 7 of 10
# Model Number: 227 with model ConstantNaive in generation 7 of 10
# Template Eval Error: ValueError("Model returned NaN due to a preprocessing transformer {'fillna': 'ffill', 'transformations': {'0': 'ClipOutliers', '1': 'Detrend', '2': 'SeasonalDifference', '3': 'AlignLastValue'}, 'transformation_params': {'0': {'method': 'clip', 'std_threshold': 3, 'fillna': None}, '1': {'model': 'GLS', 'phi': 1, 'window': None, 'transform_dict': None}, '2': {'lag_1': 12, 'method': 'Median'}, '3': {'rows': 1, 'lag': 1, 'method': 'multiplicative', 'strength': 0.2, 'first_value_only': False}}}. fail_on_forecast_nan=True") in model 227 in generation 7: ConstantNaive
# Model Number: 228 with model LastValueNaive in generation 7 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 228 in generation 7: LastValueNaive
# Model Number: 229 with model AverageValueNaive in generation 7 of 10
# Model Number: 230 with model SeasonalityMotif in generation 7 of 10
# Model Number: 231 with model AverageValueNaive in generation 7 of 10
# Model Number: 232 with model LastValueNaive in generation 7 of 10
# Model Number: 233 with model SeasonalityMotif in generation 7 of 10
# Model Number: 234 with model AverageValueNaive in generation 7 of 10
# Model Number: 235 with model SeasonalityMotif in generation 7 of 10
# Model Number: 236 with model LastValueNaive in generation 7 of 10
# Model Number: 237 with model AverageValueNaive in generation 7 of 10
# Model Number: 238 with model GLS in generation 7 of 10
# New Generation: 8 of 10
# Model Number: 239 with model AverageValueNaive in generation 8 of 10
# Model Number: 240 with model SeasonalNaive in generation 8 of 10
# Model Number: 241 with model AverageValueNaive in generation 8 of 10
# Model Number: 242 with model AverageValueNaive in generation 8 of 10
# Model Number: 243 with model LastValueNaive in generation 8 of 10
# Model Number: 244 with model AverageValueNaive in generation 8 of 10
# Model Number: 245 with model LastValueNaive in generation 8 of 10
# Model Number: 246 with model AverageValueNaive in generation 8 of 10
# Model Number: 247 with model LastValueNaive in generation 8 of 10
# Model Number: 248 with model ConstantNaive in generation 8 of 10
# Model Number: 249 with model SeasonalityMotif in generation 8 of 10
# Model Number: 250 with model LastValueNaive in generation 8 of 10
# Model Number: 251 with model AverageValueNaive in generation 8 of 10
# Model Number: 252 with model ConstantNaive in generation 8 of 10
# Model Number: 253 with model SeasonalityMotif in generation 8 of 10
# Model Number: 254 with model ConstantNaive in generation 8 of 10
# Model Number: 255 with model AverageValueNaive in generation 8 of 10
# Model Number: 256 with model AverageValueNaive in generation 8 of 10
# Model Number: 257 with model LastValueNaive in generation 8 of 10
# Model Number: 258 with model SeasonalityMotif in generation 8 of 10
# Model Number: 259 with model AverageValueNaive in generation 8 of 10
# Model Number: 260 with model SeasonalityMotif in generation 8 of 10
# Model Number: 261 with model ConstantNaive in generation 8 of 10
# Model Number: 262 with model ConstantNaive in generation 8 of 10
# New Generation: 9 of 10
# Model Number: 263 with model AverageValueNaive in generation 9 of 10
# Model Number: 264 with model ConstantNaive in generation 9 of 10
# Model Number: 265 with model LastValueNaive in generation 9 of 10
# Model Number: 266 with model AverageValueNaive in generation 9 of 10
# Model Number: 267 with model LastValueNaive in generation 9 of 10
# Model Number: 268 with model SeasonalityMotif in generation 9 of 10
# Model Number: 269 with model ConstantNaive in generation 9 of 10
# Model Number: 270 with model LastValueNaive in generation 9 of 10
# Model Number: 271 with model AverageValueNaive in generation 9 of 10
# Model Number: 272 with model LastValueNaive in generation 9 of 10
# Model Number: 273 with model AverageValueNaive in generation 9 of 10
# Model Number: 274 with model ConstantNaive in generation 9 of 10
# Model Number: 275 with model LastValueNaive in generation 9 of 10
# Model Number: 276 with model AverageValueNaive in generation 9 of 10
# Model Number: 277 with model AverageValueNaive in generation 9 of 10
# Model Number: 278 with model AverageValueNaive in generation 9 of 10
# Model Number: 279 with model LastValueNaive in generation 9 of 10
# Model Number: 280 with model LastValueNaive in generation 9 of 10
# Model Number: 281 with model AverageValueNaive in generation 9 of 10
# Model Number: 282 with model AverageValueNaive in generation 9 of 10
# Model Number: 283 with model ConstantNaive in generation 9 of 10
# Model Number: 284 with model SeasonalityMotif in generation 9 of 10
# Model Number: 285 with model LastValueNaive in generation 9 of 10
# Model Number: 286 with model AverageValueNaive in generation 9 of 10
# New Generation: 10 of 10
# Model Number: 287 with model SeasonalityMotif in generation 10 of 10
# Model Number: 288 with model LastValueNaive in generation 10 of 10
# Model Number: 289 with model AverageValueNaive in generation 10 of 10
# Model Number: 290 with model AverageValueNaive in generation 10 of 10
# Model Number: 291 with model AverageValueNaive in generation 10 of 10
# Model Number: 292 with model AverageValueNaive in generation 10 of 10
# Model Number: 293 with model AverageValueNaive in generation 10 of 10
# Model Number: 294 with model LastValueNaive in generation 10 of 10
# Model Number: 295 with model ConstantNaive in generation 10 of 10
# Model Number: 296 with model AverageValueNaive in generation 10 of 10
# Model Number: 297 with model LastValueNaive in generation 10 of 10
# Model Number: 298 with model LastValueNaive in generation 10 of 10
# Model Number: 299 with model AverageValueNaive in generation 10 of 10
# Model Number: 300 with model LastValueNaive in generation 10 of 10
# Model Number: 301 with model ConstantNaive in generation 10 of 10
# Model Number: 302 with model LastValueNaive in generation 10 of 10
# Model Number: 303 with model AverageValueNaive in generation 10 of 10
# Template Eval Error: ValueError("Model returned NaN due to a preprocessing transformer {'fillna': 'ffill', 'transformations': {'0': 'bkfilter', '1': 'SeasonalDifference', '2': 'AlignLastValue'}, 'transformation_params': {'0': {}, '1': {'lag_1': 12, 'method': 'Median'}, '2': {'rows': 1, 'lag': 1, 'method': 'multiplicative', 'strength': 0.2, 'first_value_only': False}}}. fail_on_forecast_nan=True") in model 303 in generation 10: AverageValueNaive
# Model Number: 304 with model LastValueNaive in generation 10 of 10
# Validation Round: 1
# Model Number: 1 of 46 with model AverageValueNaive for Validation 1
# 📈 1 - AverageValueNaive with avg smape 12.96:
# Model Number: 2 of 46 with model AverageValueNaive for Validation 1
# 📈 2 - AverageValueNaive with avg smape 12.35:
# Model Number: 3 of 46 with model AverageValueNaive for Validation 1
# 📈 3 - AverageValueNaive with avg smape 12.2:
# Model Number: 4 of 46 with model LastValueNaive for Validation 1
# 4 - LastValueNaive with avg smape 13.68:
# Model Number: 5 of 46 with model AverageValueNaive for Validation 1
# 📈 5 - AverageValueNaive with avg smape 12.18:
# Model Number: 6 of 46 with model AverageValueNaive for Validation 1
# 📈 6 - AverageValueNaive with avg smape 12.13:
# Model Number: 7 of 46 with model AverageValueNaive for Validation 1
# 7 - AverageValueNaive with avg smape 12.55:
# Model Number: 8 of 46 with model LastValueNaive for Validation 1
# 8 - LastValueNaive with avg smape 12.71:
# Model Number: 9 of 46 with model LastValueNaive for Validation 1
# 9 - LastValueNaive with avg smape 12.22:
# Model Number: 10 of 46 with model LastValueNaive for Validation 1
# 10 - LastValueNaive with avg smape 14.19:
# Model Number: 11 of 46 with model AverageValueNaive for Validation 1
# 11 - AverageValueNaive with avg smape 12.49:
# Model Number: 12 of 46 with model AverageValueNaive for Validation 1
# 12 - AverageValueNaive with avg smape 12.49:
# Model Number: 13 of 46 with model AverageValueNaive for Validation 1
# 13 - AverageValueNaive with avg smape 12.49:
# Model Number: 14 of 46 with model LastValueNaive for Validation 1
# 14 - LastValueNaive with avg smape 14.32:
# Model Number: 15 of 46 with model LastValueNaive for Validation 1
# 15 - LastValueNaive with avg smape 14.32:
# Model Number: 16 of 46 with model LastValueNaive for Validation 1
# 16 - LastValueNaive with avg smape 14.3:
# Model Number: 17 of 46 with model LastValueNaive for Validation 1
# 17 - LastValueNaive with avg smape 14.3:
# Model Number: 18 of 46 with model LastValueNaive for Validation 1
# 18 - LastValueNaive with avg smape 14.3:
# Model Number: 19 of 46 with model SeasonalityMotif for Validation 1
# 19 - SeasonalityMotif with avg smape 13.47:
# Model Number: 20 of 46 with model SeasonalityMotif for Validation 1
# 20 - SeasonalityMotif with avg smape 13.71:
# Model Number: 21 of 46 with model SeasonalityMotif for Validation 1
# 21 - SeasonalityMotif with avg smape 13.19:
# Model Number: 22 of 46 with model SeasonalityMotif for Validation 1
# 22 - SeasonalityMotif with avg smape 13.97:
# Model Number: 23 of 46 with model SeasonalityMotif for Validation 1
# 23 - SeasonalityMotif with avg smape 14.0:
# Model Number: 24 of 46 with model ConstantNaive for Validation 1
# 📈 24 - ConstantNaive with avg smape 12.03:
# Model Number: 25 of 46 with model ConstantNaive for Validation 1
# 📈 25 - ConstantNaive with avg smape 12.02:
# Model Number: 26 of 46 with model ConstantNaive for Validation 1
# 26 - ConstantNaive with avg smape 12.02:
# Model Number: 27 of 46 with model ConstantNaive for Validation 1
# 27 - ConstantNaive with avg smape 12.02:
# Model Number: 28 of 46 with model ConstantNaive for Validation 1
# 28 - ConstantNaive with avg smape 12.02:
# Model Number: 29 of 46 with model SeasonalityMotif for Validation 1
# 29 - SeasonalityMotif with avg smape 14.87:
# Model Number: 30 of 46 with model SeasonalityMotif for Validation 1
# 30 - SeasonalityMotif with avg smape 13.73:
# Model Number: 31 of 46 with model SeasonalNaive for Validation 1
# 31 - SeasonalNaive with avg smape 12.02:
# Model Number: 32 of 46 with model SeasonalNaive for Validation 1
# 32 - SeasonalNaive with avg smape 12.02:
# Model Number: 33 of 46 with model ConstantNaive for Validation 1
# 33 - ConstantNaive with avg smape 12.67:
# Model Number: 34 of 46 with model SeasonalityMotif for Validation 1
# 34 - SeasonalityMotif with avg smape 15.17:
# Model Number: 35 of 46 with model SeasonalityMotif for Validation 1
# 35 - SeasonalityMotif with avg smape 15.49:
# Model Number: 36 of 46 with model ConstantNaive for Validation 1
# 36 - ConstantNaive with avg smape 13.32:
# Model Number: 37 of 46 with model ConstantNaive for Validation 1
# 37 - ConstantNaive with avg smape 13.32:
# Model Number: 38 of 46 with model ConstantNaive for Validation 1
# 38 - ConstantNaive with avg smape 13.2:
# Model Number: 39 of 46 with model GLS for Validation 1
# 39 - GLS with avg smape 13.51:
# Model Number: 40 of 46 with model GLS for Validation 1
# 40 - GLS with avg smape 13.0:
# Model Number: 41 of 46 with model GLS for Validation 1
# 41 - GLS with avg smape 21.97:
# Model Number: 42 of 46 with model SeasonalNaive for Validation 1
# 42 - SeasonalNaive with avg smape 13.21:
# Model Number: 43 of 46 with model SeasonalNaive for Validation 1
# 43 - SeasonalNaive with avg smape 30.29:
# Model Number: 44 of 46 with model GLS for Validation 1
# 44 - GLS with avg smape 13.86:
# Model Number: 45 of 46 with model SeasonalNaive for Validation 1
# 45 - SeasonalNaive with avg smape 17.64:
# Model Number: 46 of 46 with model SeasonalNaive for Validation 1
# 46 - SeasonalNaive with avg smape 21.46:
# Validation Round: 2
# Model Number: 1 of 46 with model AverageValueNaive for Validation 2
# 📈 1 - AverageValueNaive with avg smape 10.04:
# Model Number: 2 of 46 with model AverageValueNaive for Validation 2
# 📈 2 - AverageValueNaive with avg smape 9.36:
# Model Number: 3 of 46 with model AverageValueNaive for Validation 2
# 3 - AverageValueNaive with avg smape 9.43:
# Model Number: 4 of 46 with model LastValueNaive for Validation 2
# 4 - LastValueNaive with avg smape 11.51:
# Model Number: 5 of 46 with model AverageValueNaive for Validation 2
# 5 - AverageValueNaive with avg smape 9.72:
# Model Number: 6 of 46 with model AverageValueNaive for Validation 2
# 6 - AverageValueNaive with avg smape 9.74:
# Model Number: 7 of 46 with model AverageValueNaive for Validation 2
# 7 - AverageValueNaive with avg smape 10.94:
# Model Number: 8 of 46 with model LastValueNaive for Validation 2
# 8 - LastValueNaive with avg smape 11.78:
# Model Number: 9 of 46 with model LastValueNaive for Validation 2
# 9 - LastValueNaive with avg smape 12.0:
# Model Number: 10 of 46 with model LastValueNaive for Validation 2
# 10 - LastValueNaive with avg smape 11.82:
# Model Number: 11 of 46 with model AverageValueNaive for Validation 2
# 11 - AverageValueNaive with avg smape 9.65:
# Model Number: 12 of 46 with model AverageValueNaive for Validation 2
# 12 - AverageValueNaive with avg smape 9.65:
# Model Number: 13 of 46 with model AverageValueNaive for Validation 2
# 13 - AverageValueNaive with avg smape 9.65:
# Model Number: 14 of 46 with model LastValueNaive for Validation 2
# 14 - LastValueNaive with avg smape 12.15:
# Model Number: 15 of 46 with model LastValueNaive for Validation 2
# 15 - LastValueNaive with avg smape 12.15:
# Model Number: 16 of 46 with model LastValueNaive for Validation 2
# 16 - LastValueNaive with avg smape 12.19:
# Model Number: 17 of 46 with model LastValueNaive for Validation 2
# 17 - LastValueNaive with avg smape 12.19:
# Model Number: 18 of 46 with model LastValueNaive for Validation 2
# 18 - LastValueNaive with avg smape 12.19:
# Model Number: 19 of 46 with model SeasonalityMotif for Validation 2
# 19 - SeasonalityMotif with avg smape 10.85:
# Model Number: 20 of 46 with model SeasonalityMotif for Validation 2
# 20 - SeasonalityMotif with avg smape 12.25:
# Model Number: 21 of 46 with model SeasonalityMotif for Validation 2
# 21 - SeasonalityMotif with avg smape 12.6:
# Model Number: 22 of 46 with model SeasonalityMotif for Validation 2
# 22 - SeasonalityMotif with avg smape 11.39:
# Model Number: 23 of 46 with model SeasonalityMotif for Validation 2
# 23 - SeasonalityMotif with avg smape 13.23:
# Model Number: 24 of 46 with model ConstantNaive for Validation 2
# 24 - ConstantNaive with avg smape 11.41:
# Model Number: 25 of 46 with model ConstantNaive for Validation 2
# 25 - ConstantNaive with avg smape 11.4:
# Model Number: 26 of 46 with model ConstantNaive for Validation 2
# 26 - ConstantNaive with avg smape 11.58:
# Model Number: 27 of 46 with model ConstantNaive for Validation 2
# 27 - ConstantNaive with avg smape 11.56:
# Model Number: 28 of 46 with model ConstantNaive for Validation 2
# 28 - ConstantNaive with avg smape 11.56:
# Model Number: 29 of 46 with model SeasonalityMotif for Validation 2
# 29 - SeasonalityMotif with avg smape 18.56:
# Model Number: 30 of 46 with model SeasonalityMotif for Validation 2
# 30 - SeasonalityMotif with avg smape 13.58:
# Model Number: 31 of 46 with model SeasonalNaive for Validation 2
# 31 - SeasonalNaive with avg smape 11.56:
# Model Number: 32 of 46 with model SeasonalNaive for Validation 2
# 32 - SeasonalNaive with avg smape 11.56:
# Model Number: 33 of 46 with model ConstantNaive for Validation 2
# 33 - ConstantNaive with avg smape 12.31:
# Model Number: 34 of 46 with model SeasonalityMotif for Validation 2
# 34 - SeasonalityMotif with avg smape 17.92:
# Model Number: 35 of 46 with model SeasonalityMotif for Validation 2
# 35 - SeasonalityMotif with avg smape 21.1:
# Model Number: 36 of 46 with model ConstantNaive for Validation 2
# 36 - ConstantNaive with avg smape 10.59:
# Model Number: 37 of 46 with model ConstantNaive for Validation 2
# 37 - ConstantNaive with avg smape 10.59:
# Model Number: 38 of 46 with model ConstantNaive for Validation 2
# 38 - ConstantNaive with avg smape 12.72:
# Model Number: 39 of 46 with model GLS for Validation 2
# 39 - GLS with avg smape 15.25:
# Model Number: 40 of 46 with model GLS for Validation 2
# 40 - GLS with avg smape 11.51:
# Model Number: 41 of 46 with model GLS for Validation 2
# 41 - GLS with avg smape 21.4:
# Model Number: 42 of 46 with model SeasonalNaive for Validation 2
# 42 - SeasonalNaive with avg smape 21.09:
# Model Number: 43 of 46 with model SeasonalNaive for Validation 2
# 43 - SeasonalNaive with avg smape 22.62:
# Model Number: 44 of 46 with model GLS for Validation 2
# 44 - GLS with avg smape 11.33:
# Model Number: 45 of 46 with model SeasonalNaive for Validation 2
# 45 - SeasonalNaive with avg smape 25.15:
# Model Number: 46 of 46 with model SeasonalNaive for Validation 2
# 46 - SeasonalNaive with avg smape 22.39:
# Validation Round: 3
# Model Number: 1 of 46 with model AverageValueNaive for Validation 3
# 📈 1 - AverageValueNaive with avg smape 13.92:
# Model Number: 2 of 46 with model AverageValueNaive for Validation 3
# 2 - AverageValueNaive with avg smape 14.87:
# Model Number: 3 of 46 with model AverageValueNaive for Validation 3
# 3 - AverageValueNaive with avg smape 14.93:
# Model Number: 4 of 46 with model LastValueNaive for Validation 3
# 📈 4 - LastValueNaive with avg smape 13.61:
# Model Number: 5 of 46 with model AverageValueNaive for Validation 3
# 5 - AverageValueNaive with avg smape 15.29:
# Model Number: 6 of 46 with model AverageValueNaive for Validation 3
# 6 - AverageValueNaive with avg smape 15.36:
# Model Number: 7 of 46 with model AverageValueNaive for Validation 3
# 7 - AverageValueNaive with avg smape 16.88:
# Model Number: 8 of 46 with model LastValueNaive for Validation 3
# 8 - LastValueNaive with avg smape 14.47:
# Model Number: 9 of 46 with model LastValueNaive for Validation 3
# 9 - LastValueNaive with avg smape 14.61:
# Model Number: 10 of 46 with model LastValueNaive for Validation 3
# 10 - LastValueNaive with avg smape 14.9:
# Model Number: 11 of 46 with model AverageValueNaive for Validation 3
# 11 - AverageValueNaive with avg smape 15.31:
# Model Number: 12 of 46 with model AverageValueNaive for Validation 3
# 12 - AverageValueNaive with avg smape 15.31:
# Model Number: 13 of 46 with model AverageValueNaive for Validation 3
# 13 - AverageValueNaive with avg smape 15.31:
# Model Number: 14 of 46 with model LastValueNaive for Validation 3
# 14 - LastValueNaive with avg smape 14.38:
# Model Number: 15 of 46 with model LastValueNaive for Validation 3
# 15 - LastValueNaive with avg smape 14.38:
# Model Number: 16 of 46 with model LastValueNaive for Validation 3
# 16 - LastValueNaive with avg smape 14.36:
# Model Number: 17 of 46 with model LastValueNaive for Validation 3
# 17 - LastValueNaive with avg smape 14.36:
# Model Number: 18 of 46 with model LastValueNaive for Validation 3
# 18 - LastValueNaive with avg smape 14.36:
# Model Number: 19 of 46 with model SeasonalityMotif for Validation 3
# 19 - SeasonalityMotif with avg smape 17.4:
# Model Number: 20 of 46 with model SeasonalityMotif for Validation 3
# 20 - SeasonalityMotif with avg smape 16.02:
# Model Number: 21 of 46 with model SeasonalityMotif for Validation 3
# 21 - SeasonalityMotif with avg smape 16.33:
# Model Number: 22 of 46 with model SeasonalityMotif for Validation 3
# 22 - SeasonalityMotif with avg smape 17.34:
# Model Number: 23 of 46 with model SeasonalityMotif for Validation 3
# 23 - SeasonalityMotif with avg smape 18.57:
# Model Number: 24 of 46 with model ConstantNaive for Validation 3
# 24 - ConstantNaive with avg smape 14.24:
# Model Number: 25 of 46 with model ConstantNaive for Validation 3
# 25 - ConstantNaive with avg smape 14.24:
# Model Number: 26 of 46 with model ConstantNaive for Validation 3
# 26 - ConstantNaive with avg smape 14.24:
# Model Number: 27 of 46 with model ConstantNaive for Validation 3
# 27 - ConstantNaive with avg smape 14.24:
# Model Number: 28 of 46 with model ConstantNaive for Validation 3
# 28 - ConstantNaive with avg smape 14.24:
# Model Number: 29 of 46 with model SeasonalityMotif for Validation 3
# 29 - SeasonalityMotif with avg smape 17.63:
# Model Number: 30 of 46 with model SeasonalityMotif for Validation 3
# 30 - SeasonalityMotif with avg smape 18.57:
# Model Number: 31 of 46 with model SeasonalNaive for Validation 3
# 31 - SeasonalNaive with avg smape 14.24:
# Model Number: 32 of 46 with model SeasonalNaive for Validation 3
# 32 - SeasonalNaive with avg smape 14.24:
# Model Number: 33 of 46 with model ConstantNaive for Validation 3
# 33 - ConstantNaive with avg smape 14.19:
# Model Number: 34 of 46 with model SeasonalityMotif for Validation 3
# 34 - SeasonalityMotif with avg smape 20.18:
# Model Number: 35 of 46 with model SeasonalityMotif for Validation 3
# 35 - SeasonalityMotif with avg smape 17.24:
# Model Number: 36 of 46 with model ConstantNaive for Validation 3
# 📈 36 - ConstantNaive with avg smape 13.32:
# Model Number: 37 of 46 with model ConstantNaive for Validation 3
# 37 - ConstantNaive with avg smape 13.32:
# Model Number: 38 of 46 with model ConstantNaive for Validation 3
# 38 - ConstantNaive with avg smape 14.56:
# Model Number: 39 of 46 with model GLS for Validation 3
# 39 - GLS with avg smape 18.65:
# Model Number: 40 of 46 with model GLS for Validation 3
# 40 - GLS with avg smape 14.6:
# Model Number: 41 of 46 with model GLS for Validation 3
# 41 - GLS with avg smape 21.68:
# Model Number: 42 of 46 with model SeasonalNaive for Validation 3
# 42 - SeasonalNaive with avg smape 16.44:
# Model Number: 43 of 46 with model SeasonalNaive for Validation 3
# 43 - SeasonalNaive with avg smape 24.61:
# Model Number: 44 of 46 with model GLS for Validation 3
# 44 - GLS with avg smape 14.15:
# Model Number: 45 of 46 with model SeasonalNaive for Validation 3
# 45 - SeasonalNaive with avg smape 22.84:
# Model Number: 46 of 46 with model SeasonalNaive for Validation 3
# 46 - SeasonalNaive with avg smape 20.44:
