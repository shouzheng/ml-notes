# %% [markdown]
# 代码来自文章[AutoTS 简洁实现](https://zhuanlan.zhihu.com/p/612771866)

# %% [markdown]
# ## 导入依赖 & 下载数据

# %%
import numpy as np
import pandas as pd
import datetime
from datetime import date, timedelta
import yfinance as yf   # we can use this library to download some finance data

# %%
d1 = date.today()
end_date = d1.strftime("%Y-%m-%d")

d2 = date.today()-timedelta(days=1000)
start_date = d2.strftime("%Y-%m-%d")

data = yf.download("BTC-USD"
                  , start = start_date
                  , end = end_date,
                  progress = False)

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-02-16  47944.457031  50341.101562  47201.304688  49199.871094
# 2021-02-17  49207.277344  52533.914062  49072.378906  52149.007812
# 2021-02-18  52140.972656  52474.105469  51015.765625  51679.796875
# 2021-02-19  51675.980469  56113.652344  50937.277344  55888.132812
# 2021-02-20  55887.335938  57505.226562  54626.558594  56099.519531
#
#                Adj Close       Volume
# Date
# 2021-02-16  49199.871094  77049582886
# 2021-02-17  52149.007812  80820545404
# 2021-02-18  51679.796875  52054723579
# 2021-02-19  55888.132812  63495496918
# 2021-02-20  56099.519531  68145460026

# %% [markdown]
# ## 数据处理

# %%
# 处理数据，将index数据设置成column数据
data["Date"] = data.index
data.reset_index(drop=True, inplace= True)

# %%
data.head()
# Out:
#            Open          High           Low         Close     Adj Close  \
# 0  47944.457031  50341.101562  47201.304688  49199.871094  49199.871094
# 1  49207.277344  52533.914062  49072.378906  52149.007812  52149.007812
# 2  52140.972656  52474.105469  51015.765625  51679.796875  51679.796875
# 3  51675.980469  56113.652344  50937.277344  55888.132812  55888.132812
# 4  55887.335938  57505.226562  54626.558594  56099.519531  56099.519531
#
#         Volume       Date
# 0  77049582886 2021-02-16
# 1  80820545404 2021-02-17
# 2  52054723579 2021-02-18
# 3  63495496918 2021-02-19
# 4  68145460026 2021-02-20

# %%
# 检查是否有null值
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Date         0
# dtype: int64

# %%
# 用plotly显示股票走势
import plotly.graph_objects as go
figure = go.Figure(go.Candlestick(x = data["Date"]
                                 ,open = data["Open"]
                                 ,close = data["Close"]
                                 ,high = data["High"]
                                 ,low = data["Low"]))
figure.update_layout(title = " Bitcoin Price Analysis",
                    xaxis_rangeslider_visible = False)
figure.show()

# %%
# 显示各参数之间的相关性
import seaborn as sns

correlation = data.corr()
correlation["Close"].sort_values(ascending = False)

sns.heatmap(correlation, cmap= "coolwarm", annot = True)
correlation
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.998135  0.996357  0.995166   0.995166  0.401296
# High       0.998135  1.000000  0.996060  0.997744   0.997744  0.414017
# Low        0.996357  0.996060  1.000000  0.997608   0.997608  0.367718
# Close      0.995166  0.997744  0.997608  1.000000   1.000000  0.390988
# Adj Close  0.995166  0.997744  0.997608  1.000000   1.000000  0.390988
# Volume     0.401296  0.414017  0.367718  0.390988   0.390988  1.000000
# Date      -0.702595 -0.710917 -0.687720 -0.700943  -0.700943 -0.585206
#
#                Date
# Open      -0.702595
# High      -0.710917
# Low       -0.687720
# Close     -0.700943
# Adj Close -0.700943
# Volume    -0.585206
# Date       1.000000

# %% [markdown]
# ## 使用AutoTS进行训练

# %%
from autots import AutoTS
model = AutoTS(forecast_length = 30, ensemble = "simple", frequency = "infer", model_list='superfast', transformer_list='superfast')
model = model.fit(data, date_col = "Date", value_col = "Close", id_col = None)
prediction = model.predict()
forecast = prediction.forecast
forecast
# Out:
# Data frequency is: D, used frequency is: D
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model GLS in generation 0 of 10
# Model Number: 5 with model GLS in generation 0 of 10
# Model Number: 6 with model LastValueNaive in generation 0 of 10
# Model Number: 7 with model LastValueNaive in generation 0 of 10
# Model Number: 8 with model LastValueNaive in generation 0 of 10
# Model Number: 9 with model LastValueNaive in generation 0 of 10
# Model Number: 10 with model SeasonalNaive in generation 0 of 10
# Model Number: 11 with model SeasonalNaive in generation 0 of 10
# Model Number: 12 with model SeasonalNaive in generation 0 of 10
# Model Number: 13 with model ConstantNaive in generation 0 of 10
# Model Number: 14 with model SeasonalNaive in generation 0 of 10
# Model Number: 15 with model SeasonalNaive in generation 0 of 10
# Model Number: 16 with model SeasonalityMotif in generation 0 of 10
# Model Number: 17 with model ConstantNaive in generation 0 of 10
# Model Number: 18 with model LastValueNaive in generation 0 of 10
# Model Number: 19 with model AverageValueNaive in generation 0 of 10
# Model Number: 20 with model GLS in generation 0 of 10
# Model Number: 21 with model SeasonalNaive in generation 0 of 10
# Model Number: 22 with model SeasonalityMotif in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model AverageValueNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalityMotif in generation 0 of 10
# Model Number: 27 with model SeasonalityMotif in generation 0 of 10
# Model Number: 28 with model AverageValueNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 28 in generation 0: AverageValueNaive
# Model Number: 29 with model ConstantNaive in generation 0 of 10
# Model Number: 30 with model LastValueNaive in generation 0 of 10
# Model Number: 31 with model ConstantNaive in generation 0 of 10
# Model Number: 32 with model LastValueNaive in generation 0 of 10
# Model Number: 33 with model LastValueNaive in generation 0 of 10
# Model Number: 34 with model SeasonalityMotif in generation 0 of 10
# Model Number: 35 with model AverageValueNaive in generation 0 of 10
# Model Number: 36 with model SeasonalNaive in generation 0 of 10
# Model Number: 37 with model AverageValueNaive in generation 0 of 10
# Model Number: 38 with model SeasonalNaive in generation 0 of 10
# Model Number: 39 with model SeasonalityMotif in generation 0 of 10
# Model Number: 40 with model ConstantNaive in generation 0 of 10
# Model Number: 41 with model ConstantNaive in generation 0 of 10
# Model Number: 42 with model GLS in generation 0 of 10
# Model Number: 43 with model ConstantNaive in generation 0 of 10
# Model Number: 44 with model AverageValueNaive in generation 0 of 10
# Model Number: 45 with model SeasonalNaive in generation 0 of 10
# Model Number: 46 with model SeasonalNaive in generation 0 of 10
# New Generation: 1 of 10
# Model Number: 47 with model LastValueNaive in generation 1 of 10
# Model Number: 48 with model SeasonalityMotif in generation 1 of 10
# Model Number: 49 with model AverageValueNaive in generation 1 of 10
# Model Number: 50 with model ConstantNaive in generation 1 of 10
# Model Number: 51 with model LastValueNaive in generation 1 of 10
# Model Number: 52 with model SeasonalNaive in generation 1 of 10
# Model Number: 53 with model AverageValueNaive in generation 1 of 10
# Model Number: 54 with model AverageValueNaive in generation 1 of 10
# Model Number: 55 with model SeasonalNaive in generation 1 of 10
# Model Number: 56 with model SeasonalNaive in generation 1 of 10
# Model Number: 57 with model LastValueNaive in generation 1 of 10
# Model Number: 58 with model LastValueNaive in generation 1 of 10
# Model Number: 59 with model ConstantNaive in generation 1 of 10
# Model Number: 60 with model ConstantNaive in generation 1 of 10
# Model Number: 61 with model LastValueNaive in generation 1 of 10
# Model Number: 62 with model SeasonalNaive in generation 1 of 10
# Model Number: 63 with model AverageValueNaive in generation 1 of 10
# Model Number: 64 with model GLS in generation 1 of 10
# Model Number: 65 with model AverageValueNaive in generation 1 of 10
# Model Number: 66 with model AverageValueNaive in generation 1 of 10
# Model Number: 67 with model SeasonalityMotif in generation 1 of 10
# Model Number: 68 with model AverageValueNaive in generation 1 of 10
# Model Number: 69 with model AverageValueNaive in generation 1 of 10
# Model Number: 70 with model ConstantNaive in generation 1 of 10
# Model Number: 71 with model SeasonalNaive in generation 1 of 10
# Model Number: 72 with model SeasonalNaive in generation 1 of 10
# Model Number: 73 with model LastValueNaive in generation 1 of 10
# Model Number: 74 with model SeasonalNaive in generation 1 of 10
# Model Number: 75 with model SeasonalityMotif in generation 1 of 10
# Model Number: 76 with model SeasonalNaive in generation 1 of 10
# New Generation: 2 of 10
# Model Number: 77 with model LastValueNaive in generation 2 of 10
# Model Number: 78 with model SeasonalityMotif in generation 2 of 10
# Model Number: 79 with model SeasonalityMotif in generation 2 of 10
# Model Number: 80 with model AverageValueNaive in generation 2 of 10
# Model Number: 81 with model LastValueNaive in generation 2 of 10
# Model Number: 82 with model ConstantNaive in generation 2 of 10
# Model Number: 83 with model ConstantNaive in generation 2 of 10
# Model Number: 84 with model LastValueNaive in generation 2 of 10
# Model Number: 85 with model SeasonalityMotif in generation 2 of 10
# Model Number: 86 with model LastValueNaive in generation 2 of 10
# Model Number: 87 with model LastValueNaive in generation 2 of 10
# Model Number: 88 with model SeasonalNaive in generation 2 of 10
# Model Number: 89 with model GLS in generation 2 of 10
# Model Number: 90 with model SeasonalNaive in generation 2 of 10
# Model Number: 91 with model GLS in generation 2 of 10
# Model Number: 92 with model LastValueNaive in generation 2 of 10
# Model Number: 93 with model GLS in generation 2 of 10
# Model Number: 94 with model AverageValueNaive in generation 2 of 10
# Model Number: 95 with model SeasonalNaive in generation 2 of 10
# Model Number: 96 with model LastValueNaive in generation 2 of 10
# Model Number: 97 with model AverageValueNaive in generation 2 of 10
# Model Number: 98 with model ConstantNaive in generation 2 of 10
# Model Number: 99 with model LastValueNaive in generation 2 of 10
# Model Number: 100 with model GLS in generation 2 of 10
# Model Number: 101 with model ConstantNaive in generation 2 of 10
# Model Number: 102 with model SeasonalityMotif in generation 2 of 10
# Model Number: 103 with model AverageValueNaive in generation 2 of 10
# Model Number: 104 with model LastValueNaive in generation 2 of 10
# Model Number: 105 with model ConstantNaive in generation 2 of 10
# Model Number: 106 with model SeasonalNaive in generation 2 of 10
# New Generation: 3 of 10
# Model Number: 107 with model AverageValueNaive in generation 3 of 10
# Model Number: 108 with model LastValueNaive in generation 3 of 10
# Model Number: 109 with model GLS in generation 3 of 10
# Model Number: 110 with model ConstantNaive in generation 3 of 10
# Model Number: 111 with model SeasonalityMotif in generation 3 of 10
# Model Number: 112 with model AverageValueNaive in generation 3 of 10
# Model Number: 113 with model LastValueNaive in generation 3 of 10
# Model Number: 114 with model AverageValueNaive in generation 3 of 10
# Model Number: 115 with model SeasonalNaive in generation 3 of 10
# Model Number: 116 with model GLS in generation 3 of 10
# Model Number: 117 with model SeasonalityMotif in generation 3 of 10
# Model Number: 118 with model GLS in generation 3 of 10
# Model Number: 119 with model SeasonalNaive in generation 3 of 10
# Model Number: 120 with model ConstantNaive in generation 3 of 10
# Model Number: 121 with model LastValueNaive in generation 3 of 10
# Model Number: 122 with model SeasonalNaive in generation 3 of 10
# Model Number: 123 with model GLS in generation 3 of 10
# Model Number: 124 with model SeasonalNaive in generation 3 of 10
# Model Number: 125 with model LastValueNaive in generation 3 of 10
# Model Number: 126 with model AverageValueNaive in generation 3 of 10
# Model Number: 127 with model AverageValueNaive in generation 3 of 10
# Model Number: 128 with model SeasonalityMotif in generation 3 of 10
# Model Number: 129 with model ConstantNaive in generation 3 of 10
# Model Number: 130 with model AverageValueNaive in generation 3 of 10
# Model Number: 131 with model ConstantNaive in generation 3 of 10
# Model Number: 132 with model LastValueNaive in generation 3 of 10
# Model Number: 133 with model GLS in generation 3 of 10
# Model Number: 134 with model SeasonalNaive in generation 3 of 10
# Model Number: 135 with model AverageValueNaive in generation 3 of 10
# Model Number: 136 with model SeasonalNaive in generation 3 of 10
# New Generation: 4 of 10
# Model Number: 137 with model AverageValueNaive in generation 4 of 10
# Model Number: 138 with model ConstantNaive in generation 4 of 10
# Model Number: 139 with model SeasonalNaive in generation 4 of 10
# Model Number: 140 with model GLS in generation 4 of 10
# Model Number: 141 with model SeasonalNaive in generation 4 of 10
# Model Number: 142 with model SeasonalNaive in generation 4 of 10
# Model Number: 143 with model AverageValueNaive in generation 4 of 10
# Model Number: 144 with model SeasonalNaive in generation 4 of 10
# Model Number: 145 with model SeasonalNaive in generation 4 of 10
# Model Number: 146 with model ConstantNaive in generation 4 of 10
# Model Number: 147 with model AverageValueNaive in generation 4 of 10
# Model Number: 148 with model LastValueNaive in generation 4 of 10
# Model Number: 149 with model AverageValueNaive in generation 4 of 10
# Model Number: 150 with model AverageValueNaive in generation 4 of 10
# Model Number: 151 with model GLS in generation 4 of 10
# Model Number: 152 with model AverageValueNaive in generation 4 of 10
# Model Number: 153 with model ConstantNaive in generation 4 of 10
# Model Number: 154 with model ConstantNaive in generation 4 of 10
# Model Number: 155 with model SeasonalityMotif in generation 4 of 10
# Model Number: 156 with model GLS in generation 4 of 10
# Model Number: 157 with model ConstantNaive in generation 4 of 10
# Model Number: 158 with model LastValueNaive in generation 4 of 10
# Model Number: 159 with model ConstantNaive in generation 4 of 10
# Model Number: 160 with model ConstantNaive in generation 4 of 10
# Model Number: 161 with model GLS in generation 4 of 10
# Model Number: 162 with model AverageValueNaive in generation 4 of 10
# Model Number: 163 with model AverageValueNaive in generation 4 of 10
# Model Number: 164 with model GLS in generation 4 of 10
# Model Number: 165 with model LastValueNaive in generation 4 of 10
# Model Number: 166 with model LastValueNaive in generation 4 of 10
# New Generation: 5 of 10
# Model Number: 167 with model AverageValueNaive in generation 5 of 10
# Model Number: 168 with model ConstantNaive in generation 5 of 10
# Model Number: 169 with model SeasonalNaive in generation 5 of 10
# Model Number: 170 with model GLS in generation 5 of 10
# Model Number: 171 with model GLS in generation 5 of 10
# Model Number: 172 with model LastValueNaive in generation 5 of 10
# Model Number: 173 with model SeasonalNaive in generation 5 of 10
# Model Number: 174 with model AverageValueNaive in generation 5 of 10
# Model Number: 175 with model SeasonalNaive in generation 5 of 10
# Model Number: 176 with model ConstantNaive in generation 5 of 10
# Model Number: 177 with model SeasonalNaive in generation 5 of 10
# Model Number: 178 with model AverageValueNaive in generation 5 of 10
# Model Number: 179 with model ConstantNaive in generation 5 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 179 in generation 5: ConstantNaive
# Model Number: 180 with model ConstantNaive in generation 5 of 10
# Model Number: 181 with model AverageValueNaive in generation 5 of 10
# Model Number: 182 with model GLS in generation 5 of 10
# Model Number: 183 with model LastValueNaive in generation 5 of 10
# Model Number: 184 with model GLS in generation 5 of 10
# Model Number: 185 with model AverageValueNaive in generation 5 of 10
# Model Number: 186 with model LastValueNaive in generation 5 of 10
# Model Number: 187 with model ConstantNaive in generation 5 of 10
# Model Number: 188 with model LastValueNaive in generation 5 of 10
# Model Number: 189 with model AverageValueNaive in generation 5 of 10
# Model Number: 190 with model AverageValueNaive in generation 5 of 10
# New Generation: 6 of 10
# Model Number: 191 with model LastValueNaive in generation 6 of 10
# Model Number: 192 with model GLS in generation 6 of 10
# Model Number: 193 with model AverageValueNaive in generation 6 of 10
# Model Number: 194 with model ConstantNaive in generation 6 of 10
# Model Number: 195 with model LastValueNaive in generation 6 of 10
# Model Number: 196 with model AverageValueNaive in generation 6 of 10
# Model Number: 197 with model AverageValueNaive in generation 6 of 10
# Model Number: 198 with model AverageValueNaive in generation 6 of 10
# Model Number: 199 with model AverageValueNaive in generation 6 of 10
# Model Number: 200 with model AverageValueNaive in generation 6 of 10
# Model Number: 201 with model ConstantNaive in generation 6 of 10
# Model Number: 202 with model ConstantNaive in generation 6 of 10
# Model Number: 203 with model ConstantNaive in generation 6 of 10
# Model Number: 204 with model AverageValueNaive in generation 6 of 10
# Model Number: 205 with model LastValueNaive in generation 6 of 10
# Model Number: 206 with model GLS in generation 6 of 10
# Model Number: 207 with model GLS in generation 6 of 10
# Model Number: 208 with model SeasonalNaive in generation 6 of 10
# Model Number: 209 with model AverageValueNaive in generation 6 of 10
# Model Number: 210 with model GLS in generation 6 of 10
# Model Number: 211 with model ConstantNaive in generation 6 of 10
# Model Number: 212 with model SeasonalNaive in generation 6 of 10
# Model Number: 213 with model AverageValueNaive in generation 6 of 10
# Model Number: 214 with model GLS in generation 6 of 10
# New Generation: 7 of 10
# Model Number: 215 with model GLS in generation 7 of 10
# Model Number: 216 with model GLS in generation 7 of 10
# Model Number: 217 with model LastValueNaive in generation 7 of 10
# Model Number: 218 with model AverageValueNaive in generation 7 of 10
# Model Number: 219 with model ConstantNaive in generation 7 of 10
# Model Number: 220 with model ConstantNaive in generation 7 of 10
# Model Number: 221 with model SeasonalNaive in generation 7 of 10
# Model Number: 222 with model ConstantNaive in generation 7 of 10
# Model Number: 223 with model AverageValueNaive in generation 7 of 10
# Model Number: 224 with model LastValueNaive in generation 7 of 10
# Model Number: 225 with model LastValueNaive in generation 7 of 10
# Model Number: 226 with model GLS in generation 7 of 10
# Model Number: 227 with model ConstantNaive in generation 7 of 10
# Model Number: 228 with model ConstantNaive in generation 7 of 10
# Model Number: 229 with model SeasonalNaive in generation 7 of 10
# Model Number: 230 with model AverageValueNaive in generation 7 of 10
# Model Number: 231 with model AverageValueNaive in generation 7 of 10
# Model Number: 232 with model AverageValueNaive in generation 7 of 10
# Model Number: 233 with model AverageValueNaive in generation 7 of 10
# Model Number: 234 with model SeasonalNaive in generation 7 of 10
# Model Number: 235 with model AverageValueNaive in generation 7 of 10
# Model Number: 236 with model ConstantNaive in generation 7 of 10
# Model Number: 237 with model AverageValueNaive in generation 7 of 10
# Model Number: 238 with model AverageValueNaive in generation 7 of 10
# New Generation: 8 of 10
# Model Number: 239 with model ConstantNaive in generation 8 of 10
# Model Number: 240 with model AverageValueNaive in generation 8 of 10
# Model Number: 241 with model ConstantNaive in generation 8 of 10
# Model Number: 242 with model GLS in generation 8 of 10
# Model Number: 243 with model AverageValueNaive in generation 8 of 10
# Model Number: 244 with model ConstantNaive in generation 8 of 10
# Model Number: 245 with model GLS in generation 8 of 10
# Model Number: 246 with model GLS in generation 8 of 10
# Model Number: 247 with model AverageValueNaive in generation 8 of 10
# Model Number: 248 with model SeasonalNaive in generation 8 of 10
# Model Number: 249 with model ConstantNaive in generation 8 of 10
# Model Number: 250 with model GLS in generation 8 of 10
# Model Number: 251 with model ConstantNaive in generation 8 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 251 in generation 8: ConstantNaive
# Model Number: 252 with model SeasonalNaive in generation 8 of 10
# Model Number: 253 with model ConstantNaive in generation 8 of 10
# Model Number: 254 with model ConstantNaive in generation 8 of 10
# Model Number: 255 with model ConstantNaive in generation 8 of 10
# Model Number: 256 with model AverageValueNaive in generation 8 of 10
# Model Number: 257 with model ConstantNaive in generation 8 of 10
# Model Number: 258 with model LastValueNaive in generation 8 of 10
# Model Number: 259 with model SeasonalNaive in generation 8 of 10
# Model Number: 260 with model LastValueNaive in generation 8 of 10
# Model Number: 261 with model GLS in generation 8 of 10
# Model Number: 262 with model AverageValueNaive in generation 8 of 10
# New Generation: 9 of 10
# Model Number: 263 with model SeasonalNaive in generation 9 of 10
# Model Number: 264 with model AverageValueNaive in generation 9 of 10
# Model Number: 265 with model GLS in generation 9 of 10
# Model Number: 266 with model ConstantNaive in generation 9 of 10
# Model Number: 267 with model LastValueNaive in generation 9 of 10
# Model Number: 268 with model AverageValueNaive in generation 9 of 10
# Model Number: 269 with model GLS in generation 9 of 10
# Model Number: 270 with model LastValueNaive in generation 9 of 10
# Model Number: 271 with model GLS in generation 9 of 10
# Model Number: 272 with model LastValueNaive in generation 9 of 10
# Model Number: 273 with model SeasonalNaive in generation 9 of 10
# Model Number: 274 with model ConstantNaive in generation 9 of 10
# Model Number: 275 with model ConstantNaive in generation 9 of 10
# Model Number: 276 with model GLS in generation 9 of 10
# Model Number: 277 with model AverageValueNaive in generation 9 of 10
# Model Number: 278 with model GLS in generation 9 of 10
# Model Number: 279 with model AverageValueNaive in generation 9 of 10
# Model Number: 280 with model ConstantNaive in generation 9 of 10
# Model Number: 281 with model AverageValueNaive in generation 9 of 10
# Model Number: 282 with model GLS in generation 9 of 10
# Model Number: 283 with model AverageValueNaive in generation 9 of 10
# Model Number: 284 with model ConstantNaive in generation 9 of 10
# Model Number: 285 with model LastValueNaive in generation 9 of 10
# Model Number: 286 with model SeasonalNaive in generation 9 of 10
# New Generation: 10 of 10
# Model Number: 287 with model ConstantNaive in generation 10 of 10
# Model Number: 288 with model ConstantNaive in generation 10 of 10
# Model Number: 289 with model ConstantNaive in generation 10 of 10
# Model Number: 290 with model AverageValueNaive in generation 10 of 10
# Model Number: 291 with model AverageValueNaive in generation 10 of 10
# Model Number: 292 with model AverageValueNaive in generation 10 of 10
# Model Number: 293 with model ConstantNaive in generation 10 of 10
# Model Number: 294 with model GLS in generation 10 of 10
# Model Number: 295 with model GLS in generation 10 of 10
# Model Number: 296 with model ConstantNaive in generation 10 of 10
# Model Number: 297 with model AverageValueNaive in generation 10 of 10
# Model Number: 298 with model ConstantNaive in generation 10 of 10
# Model Number: 299 with model SeasonalNaive in generation 10 of 10
# Model Number: 300 with model SeasonalNaive in generation 10 of 10
# Model Number: 301 with model ConstantNaive in generation 10 of 10
# Model Number: 302 with model ConstantNaive in generation 10 of 10
# Model Number: 303 with model AverageValueNaive in generation 10 of 10
# Model Number: 304 with model SeasonalNaive in generation 10 of 10
# Model Number: 305 with model Ensemble in generation 11 of Ensembles
# Model Number: 306 with model Ensemble in generation 11 of Ensembles
# Model Number: 307 with model Ensemble in generation 11 of Ensembles
# Model Number: 308 with model Ensemble in generation 11 of Ensembles
# Model Number: 309 with model Ensemble in generation 11 of Ensembles
# Model Number: 310 with model Ensemble in generation 11 of Ensembles
# Model Number: 311 with model Ensemble in generation 11 of Ensembles
# Model Number: 312 with model Ensemble in generation 11 of Ensembles
# Validation Round: 1
# Model Number: 1 of 47 with model Ensemble for Validation 1
# 📈 1 - Ensemble with avg smape 28.96:
# Model Number: 2 of 47 with model Ensemble for Validation 1
# 📈 2 - Ensemble with avg smape 24.06:
# Model Number: 3 of 47 with model ConstantNaive for Validation 1
# 3 - ConstantNaive with avg smape 32.12:
# Model Number: 4 of 47 with model ConstantNaive for Validation 1
# 4 - ConstantNaive with avg smape 32.12:
# Model Number: 5 of 47 with model Ensemble for Validation 1
# 5 - Ensemble with avg smape 25.94:
# Model Number: 6 of 47 with model Ensemble for Validation 1
# 6 - Ensemble with avg smape 26.19:
# Model Number: 7 of 47 with model Ensemble for Validation 1
# 7 - Ensemble with avg smape 24.71:
# Model Number: 8 of 47 with model Ensemble for Validation 1
# 📈 8 - Ensemble with avg smape 23.37:
# Model Number: 9 of 47 with model SeasonalNaive for Validation 1
# 9 - SeasonalNaive with avg smape 23.8:
# Model Number: 10 of 47 with model AverageValueNaive for Validation 1
# 📈 10 - AverageValueNaive with avg smape 22.06:
# Model Number: 11 of 47 with model AverageValueNaive for Validation 1
# 11 - AverageValueNaive with avg smape 22.06:
# Model Number: 12 of 47 with model SeasonalNaive for Validation 1
# 📈 12 - SeasonalNaive with avg smape 19.82:
# Model Number: 13 of 47 with model AverageValueNaive for Validation 1
# 13 - AverageValueNaive with avg smape 22.3:
# Model Number: 14 of 47 with model AverageValueNaive for Validation 1
# 14 - AverageValueNaive with avg smape 20.01:
# Model Number: 15 of 47 with model AverageValueNaive for Validation 1
# 📈 15 - AverageValueNaive with avg smape 19.59:
# Model Number: 16 of 47 with model ConstantNaive for Validation 1
# 16 - ConstantNaive with avg smape 24.95:
# Model Number: 17 of 47 with model ConstantNaive for Validation 1
# 17 - ConstantNaive with avg smape 24.95:
# Model Number: 18 of 47 with model ConstantNaive for Validation 1
# 18 - ConstantNaive with avg smape 24.95:
# Model Number: 19 of 47 with model ConstantNaive for Validation 1
# 19 - ConstantNaive with avg smape 25.31:
# Model Number: 20 of 47 with model ConstantNaive for Validation 1
# 20 - ConstantNaive with avg smape 25.39:
# Model Number: 21 of 47 with model SeasonalNaive for Validation 1
# 📈 21 - SeasonalNaive with avg smape 12.83:
# Model Number: 22 of 47 with model ConstantNaive for Validation 1
# 22 - ConstantNaive with avg smape 22.07:
# Model Number: 23 of 47 with model ConstantNaive for Validation 1
# 23 - ConstantNaive with avg smape 27.4:
# Model Number: 24 of 47 with model AverageValueNaive for Validation 1
# 24 - AverageValueNaive with avg smape 24.99:
# Model Number: 25 of 47 with model AverageValueNaive for Validation 1
# 25 - AverageValueNaive with avg smape 24.94:
# Model Number: 26 of 47 with model AverageValueNaive for Validation 1
# 26 - AverageValueNaive with avg smape 24.94:
# Model Number: 27 of 47 with model AverageValueNaive for Validation 1
# 27 - AverageValueNaive with avg smape 24.95:
# Model Number: 28 of 47 with model LastValueNaive for Validation 1
# 28 - LastValueNaive with avg smape 17.45:
# Model Number: 29 of 47 with model SeasonalNaive for Validation 1
# 29 - SeasonalNaive with avg smape 27.81:
# Model Number: 30 of 47 with model GLS for Validation 1
# 30 - GLS with avg smape 22.35:
# Model Number: 31 of 47 with model GLS for Validation 1
# 31 - GLS with avg smape 24.54:
# Model Number: 32 of 47 with model GLS for Validation 1
# 32 - GLS with avg smape 24.82:
# Model Number: 33 of 47 with model LastValueNaive for Validation 1
# 33 - LastValueNaive with avg smape 19.44:
# Model Number: 34 of 47 with model LastValueNaive for Validation 1
# 34 - LastValueNaive with avg smape 19.44:
# Model Number: 35 of 47 with model LastValueNaive for Validation 1
# 35 - LastValueNaive with avg smape 19.44:
# Model Number: 36 of 47 with model GLS for Validation 1
# 36 - GLS with avg smape 24.86:
# Model Number: 37 of 47 with model GLS for Validation 1
# 37 - GLS with avg smape 25.25:
# Model Number: 38 of 47 with model GLS for Validation 1
# 38 - GLS with avg smape 25.28:
# Model Number: 39 of 47 with model GLS for Validation 1
# 39 - GLS with avg smape 24.82:
# Model Number: 40 of 47 with model GLS for Validation 1
# 40 - GLS with avg smape 25.89:
# Model Number: 41 of 47 with model GLS for Validation 1
# 41 - GLS with avg smape 25.89:
# Model Number: 42 of 47 with model SeasonalNaive for Validation 1
# 📈 42 - SeasonalNaive with avg smape 9.48:
# Model Number: 43 of 47 with model SeasonalNaive for Validation 1
# 43 - SeasonalNaive with avg smape 29.32:
# Model Number: 44 of 47 with model SeasonalNaive for Validation 1
# 44 - SeasonalNaive with avg smape 30.47:
# Model Number: 45 of 47 with model SeasonalNaive for Validation 1
# 📈 45 - SeasonalNaive with avg smape 6.24:
# Model Number: 46 of 47 with model SeasonalNaive for Validation 1
# 46 - SeasonalNaive with avg smape 29.93:
# Model Number: 47 of 47 with model Ensemble for Validation 1
# 47 - Ensemble with avg smape 17.39:
# Validation Round: 2
# Model Number: 1 of 47 with model Ensemble for Validation 2
# 📈 1 - Ensemble with avg smape 23.83:
# Model Number: 2 of 47 with model Ensemble for Validation 2
# 2 - Ensemble with avg smape 25.51:
# Model Number: 3 of 47 with model ConstantNaive for Validation 2
# 📈 3 - ConstantNaive with avg smape 22.31:
# Model Number: 4 of 47 with model ConstantNaive for Validation 2
# 4 - ConstantNaive with avg smape 22.31:
# Model Number: 5 of 47 with model Ensemble for Validation 2
# 5 - Ensemble with avg smape 22.91:
# Model Number: 6 of 47 with model Ensemble for Validation 2
# 6 - Ensemble with avg smape 25.09:
# Model Number: 7 of 47 with model Ensemble for Validation 2
# 7 - Ensemble with avg smape 22.68:
# Model Number: 8 of 47 with model Ensemble for Validation 2
# 8 - Ensemble with avg smape 24.1:
# Model Number: 9 of 47 with model SeasonalNaive for Validation 2
# 9 - SeasonalNaive with avg smape 26.09:
# Model Number: 10 of 47 with model AverageValueNaive for Validation 2
# 10 - AverageValueNaive with avg smape 26.82:
# Model Number: 11 of 47 with model AverageValueNaive for Validation 2
# 11 - AverageValueNaive with avg smape 26.82:
# Model Number: 12 of 47 with model SeasonalNaive for Validation 2
# 12 - SeasonalNaive with avg smape 22.7:
# Model Number: 13 of 47 with model AverageValueNaive for Validation 2
# 13 - AverageValueNaive with avg smape 26.77:
# Model Number: 14 of 47 with model AverageValueNaive for Validation 2
# 14 - AverageValueNaive with avg smape 25.57:
# Model Number: 15 of 47 with model AverageValueNaive for Validation 2
# 15 - AverageValueNaive with avg smape 26.62:
# Model Number: 16 of 47 with model ConstantNaive for Validation 2
# 16 - ConstantNaive with avg smape 28.44:
# Model Number: 17 of 47 with model ConstantNaive for Validation 2
# 17 - ConstantNaive with avg smape 28.44:
# Model Number: 18 of 47 with model ConstantNaive for Validation 2
# 18 - ConstantNaive with avg smape 28.44:
# Model Number: 19 of 47 with model ConstantNaive for Validation 2
# 19 - ConstantNaive with avg smape 28.74:
# Model Number: 20 of 47 with model ConstantNaive for Validation 2
# 20 - ConstantNaive with avg smape 28.81:
# Model Number: 21 of 47 with model SeasonalNaive for Validation 2
# 📈 21 - SeasonalNaive with avg smape 19.27:
# Model Number: 22 of 47 with model ConstantNaive for Validation 2
# 22 - ConstantNaive with avg smape 26.61:
# Model Number: 23 of 47 with model ConstantNaive for Validation 2
# 23 - ConstantNaive with avg smape 30.81:
# Model Number: 24 of 47 with model AverageValueNaive for Validation 2
# 24 - AverageValueNaive with avg smape 28.67:
# Model Number: 25 of 47 with model AverageValueNaive for Validation 2
# 25 - AverageValueNaive with avg smape 28.43:
# Model Number: 26 of 47 with model AverageValueNaive for Validation 2
# 26 - AverageValueNaive with avg smape 28.43:
# Model Number: 27 of 47 with model AverageValueNaive for Validation 2
# 27 - AverageValueNaive with avg smape 28.45:
# Model Number: 28 of 47 with model LastValueNaive for Validation 2
# 28 - LastValueNaive with avg smape 19.5:
# Model Number: 29 of 47 with model SeasonalNaive for Validation 2
# 29 - SeasonalNaive with avg smape 29.02:
# Model Number: 30 of 47 with model GLS for Validation 2
# 30 - GLS with avg smape 25.82:
# Model Number: 31 of 47 with model GLS for Validation 2
# 31 - GLS with avg smape 28.05:
# Model Number: 32 of 47 with model GLS for Validation 2
# 32 - GLS with avg smape 28.45:
# Model Number: 33 of 47 with model LastValueNaive for Validation 2
# 📈 33 - LastValueNaive with avg smape 17.91:
# Model Number: 34 of 47 with model LastValueNaive for Validation 2
# 34 - LastValueNaive with avg smape 17.91:
# Model Number: 35 of 47 with model LastValueNaive for Validation 2
# 35 - LastValueNaive with avg smape 17.91:
# Model Number: 36 of 47 with model GLS for Validation 2
# 36 - GLS with avg smape 28.32:
# Model Number: 37 of 47 with model GLS for Validation 2
# 37 - GLS with avg smape 28.8:
# Model Number: 38 of 47 with model GLS for Validation 2
# 38 - GLS with avg smape 28.66:
# Model Number: 39 of 47 with model GLS for Validation 2
# 39 - GLS with avg smape 28.42:
# Model Number: 40 of 47 with model GLS for Validation 2
# 40 - GLS with avg smape 29.34:
# Model Number: 41 of 47 with model GLS for Validation 2
# 41 - GLS with avg smape 29.34:
# Model Number: 42 of 47 with model SeasonalNaive for Validation 2
# 42 - SeasonalNaive with avg smape 21.83:
# Model Number: 43 of 47 with model SeasonalNaive for Validation 2
# 43 - SeasonalNaive with avg smape 30.79:
# Model Number: 44 of 47 with model SeasonalNaive for Validation 2
# 44 - SeasonalNaive with avg smape 32.2:
# Model Number: 45 of 47 with model SeasonalNaive for Validation 2
# 📈 45 - SeasonalNaive with avg smape 6.21:
# Model Number: 46 of 47 with model SeasonalNaive for Validation 2
# 46 - SeasonalNaive with avg smape 30.75:
# Model Number: 47 of 47 with model Ensemble for Validation 2
# 47 - Ensemble with avg smape 17.6:
# Validation Round: 3
# Model Number: 1 of 47 with model Ensemble for Validation 3
# 📈 1 - Ensemble with avg smape 51.22:
# Model Number: 2 of 47 with model Ensemble for Validation 3
# 📈 2 - Ensemble with avg smape 16.34:
# Model Number: 3 of 47 with model ConstantNaive for Validation 3
# 3 - ConstantNaive with avg smape 63.22:
# Model Number: 4 of 47 with model ConstantNaive for Validation 3
# 4 - ConstantNaive with avg smape 63.22:
# Model Number: 5 of 47 with model Ensemble for Validation 3
# 5 - Ensemble with avg smape 46.93:
# Model Number: 6 of 47 with model Ensemble for Validation 3
# 6 - Ensemble with avg smape 34.45:
# Model Number: 7 of 47 with model Ensemble for Validation 3
# 7 - Ensemble with avg smape 45.95:
# Model Number: 8 of 47 with model Ensemble for Validation 3
# 8 - Ensemble with avg smape 37.39:
# Model Number: 9 of 47 with model SeasonalNaive for Validation 3
# 📈 9 - SeasonalNaive with avg smape 9.91:
# Model Number: 10 of 47 with model AverageValueNaive for Validation 3
# 10 - AverageValueNaive with avg smape 16.33:
# Model Number: 11 of 47 with model AverageValueNaive for Validation 3
# 11 - AverageValueNaive with avg smape 16.33:
# Model Number: 12 of 47 with model SeasonalNaive for Validation 3
# 📈 12 - SeasonalNaive with avg smape 8.95:
# Model Number: 13 of 47 with model AverageValueNaive for Validation 3
# 13 - AverageValueNaive with avg smape 16.14:
# Model Number: 14 of 47 with model AverageValueNaive for Validation 3
# 14 - AverageValueNaive with avg smape 16.29:
# Model Number: 15 of 47 with model AverageValueNaive for Validation 3
# 15 - AverageValueNaive with avg smape 16.35:
# Model Number: 16 of 47 with model ConstantNaive for Validation 3
# 16 - ConstantNaive with avg smape 17.64:
# Model Number: 17 of 47 with model ConstantNaive for Validation 3
# 17 - ConstantNaive with avg smape 17.64:
# Model Number: 18 of 47 with model ConstantNaive for Validation 3
# 18 - ConstantNaive with avg smape 17.64:
# Model Number: 19 of 47 with model ConstantNaive for Validation 3
# 19 - ConstantNaive with avg smape 17.93:
# Model Number: 20 of 47 with model ConstantNaive for Validation 3
# 20 - ConstantNaive with avg smape 18.0:
# Model Number: 21 of 47 with model SeasonalNaive for Validation 3
# 📈 21 - SeasonalNaive with avg smape 7.72:
# Model Number: 22 of 47 with model ConstantNaive for Validation 3
# 22 - ConstantNaive with avg smape 17.89:
# Model Number: 23 of 47 with model ConstantNaive for Validation 3
# 23 - ConstantNaive with avg smape 19.96:
# Model Number: 24 of 47 with model AverageValueNaive for Validation 3
# 24 - AverageValueNaive with avg smape 17.55:
# Model Number: 25 of 47 with model AverageValueNaive for Validation 3
# 25 - AverageValueNaive with avg smape 17.63:
# Model Number: 26 of 47 with model AverageValueNaive for Validation 3
# 26 - AverageValueNaive with avg smape 17.63:
# Model Number: 27 of 47 with model AverageValueNaive for Validation 3
# 27 - AverageValueNaive with avg smape 17.64:
# Model Number: 28 of 47 with model LastValueNaive for Validation 3
# 28 - LastValueNaive with avg smape 53.04:
# Model Number: 29 of 47 with model SeasonalNaive for Validation 3
# 29 - SeasonalNaive with avg smape 12.81:
# Model Number: 30 of 47 with model GLS for Validation 3
# 30 - GLS with avg smape 14.97:
# Model Number: 31 of 47 with model GLS for Validation 3
# 31 - GLS with avg smape 17.24:
# Model Number: 32 of 47 with model GLS for Validation 3
# 32 - GLS with avg smape 17.2:
# Model Number: 33 of 47 with model LastValueNaive for Validation 3
# 33 - LastValueNaive with avg smape 57.66:
# Model Number: 34 of 47 with model LastValueNaive for Validation 3
# 34 - LastValueNaive with avg smape 57.66:
# Model Number: 35 of 47 with model LastValueNaive for Validation 3
# 35 - LastValueNaive with avg smape 57.66:
# Model Number: 36 of 47 with model GLS for Validation 3
# 36 - GLS with avg smape 17.46:
# Model Number: 37 of 47 with model GLS for Validation 3
# 37 - GLS with avg smape 17.47:
# Model Number: 38 of 47 with model GLS for Validation 3
# 38 - GLS with avg smape 17.87:
# Model Number: 39 of 47 with model GLS for Validation 3
# 39 - GLS with avg smape 17.36:
# Model Number: 40 of 47 with model GLS for Validation 3
# 40 - GLS with avg smape 18.53:
# Model Number: 41 of 47 with model GLS for Validation 3
# 41 - GLS with avg smape 18.53:
# Model Number: 42 of 47 with model SeasonalNaive for Validation 3
# 42 - SeasonalNaive with avg smape 9.03:
# Model Number: 43 of 47 with model SeasonalNaive for Validation 3
# 43 - SeasonalNaive with avg smape 14.27:
# Model Number: 44 of 47 with model SeasonalNaive for Validation 3
# 44 - SeasonalNaive with avg smape 16.17:
# Model Number: 45 of 47 with model SeasonalNaive for Validation 3
# 45 - SeasonalNaive with avg smape 16.64:
# Model Number: 46 of 47 with model SeasonalNaive for Validation 3
# 46 - SeasonalNaive with avg smape 14.56:
# Model Number: 47 of 47 with model Ensemble for Validation 3
# 47 - Ensemble with avg smape 8.23:
# Model Number: 454 with model Ensemble in generation 12 of Ensembles
# Model Number: 455 with model Ensemble in generation 12 of Ensembles
# Model Number: 456 with model Ensemble in generation 12 of Ensembles
# Model Number: 457 with model Ensemble in generation 12 of Ensembles
# Model Number: 458 with model Ensemble in generation 12 of Ensembles
# Model Number: 459 with model Ensemble in generation 12 of Ensembles
# Model Number: 460 with model Ensemble in generation 12 of Ensembles
# Model Number: 461 with model Ensemble in generation 12 of Ensembles
# Validation Round: 1
# Model Number: 1 of 8 with model Ensemble for Validation 1
# 📈 1 - Ensemble with avg smape 9.62:
# Model Number: 2 of 8 with model Ensemble for Validation 1
# 2 - Ensemble with avg smape 13.95:
# Model Number: 3 of 8 with model Ensemble for Validation 1
# 3 - Ensemble with avg smape 12.36:
# Model Number: 4 of 8 with model Ensemble for Validation 1
# 4 - Ensemble with avg smape 15.96:
# Model Number: 5 of 8 with model Ensemble for Validation 1
# 5 - Ensemble with avg smape 14.79:
# Model Number: 6 of 8 with model Ensemble for Validation 1
# 6 - Ensemble with avg smape 18.94:
# Model Number: 7 of 8 with model Ensemble for Validation 1
# 7 - Ensemble with avg smape 13.9:
# Model Number: 8 of 8 with model Ensemble for Validation 1
# 8 - Ensemble with avg smape 14.79:
# Validation Round: 2
# Model Number: 1 of 8 with model Ensemble for Validation 2
# 📈 1 - Ensemble with avg smape 15.86:
# Model Number: 2 of 8 with model Ensemble for Validation 2
# 2 - Ensemble with avg smape 19.18:
# Model Number: 3 of 8 with model Ensemble for Validation 2
# 📈 3 - Ensemble with avg smape 14.38:
# Model Number: 4 of 8 with model Ensemble for Validation 2
# 4 - Ensemble with avg smape 19.3:
# Model Number: 5 of 8 with model Ensemble for Validation 2
# 5 - Ensemble with avg smape 16.69:
# Model Number: 6 of 8 with model Ensemble for Validation 2
# 6 - Ensemble with avg smape 21.88:
# Model Number: 7 of 8 with model Ensemble for Validation 2
# 7 - Ensemble with avg smape 15.39:
# Model Number: 8 of 8 with model Ensemble for Validation 2
# 8 - Ensemble with avg smape 16.69:
# Validation Round: 3
# Model Number: 1 of 8 with model Ensemble for Validation 3
# 📈 1 - Ensemble with avg smape 4.89:
# Model Number: 2 of 8 with model Ensemble for Validation 3
# 2 - Ensemble with avg smape 6.9:
# Model Number: 3 of 8 with model Ensemble for Validation 3
# 📈 3 - Ensemble with avg smape 4.33:
# Model Number: 4 of 8 with model Ensemble for Validation 3
# 4 - Ensemble with avg smape 8.3:
# Model Number: 5 of 8 with model Ensemble for Validation 3
# 5 - Ensemble with avg smape 4.33:
# Model Number: 6 of 8 with model Ensemble for Validation 3
# 6 - Ensemble with avg smape 12.55:
# Model Number: 7 of 8 with model Ensemble for Validation 3
# 📈 7 - Ensemble with avg smape 2.95:
# Model Number: 8 of 8 with model Ensemble for Validation 3
# 8 - Ensemble with avg smape 4.33:
#                    Close
# 2023-11-13  34806.793858
# 2023-11-14  34573.593479
# 2023-11-15  34326.818349
# 2023-11-16  34123.288120
# 2023-11-17  34275.818097
# 2023-11-18  34209.970569
# 2023-11-19  34427.117041
# 2023-11-20  34346.160757
# 2023-11-21  35143.321622
# 2023-11-22  35322.603066
# 2023-11-23  35385.782627
# 2023-11-24  34992.884618
# 2023-11-25  34907.731108
# 2023-11-26  34977.078176
# 2023-11-27  34931.385587
# 2023-11-28  34999.875361
# 2023-11-29  35146.963386
# 2023-11-30  34913.005592
# 2023-12-01  34977.074450
# 2023-12-02  34829.622227
# 2023-12-03  35556.770571
# 2023-12-04  35972.006671
# 2023-12-05  36111.620752
# 2023-12-06  36498.498933
# 2023-12-07  36253.262630
# 2023-12-08  36173.656181
# 2023-12-09  36220.988362
# 2023-12-10  36248.644855
# 2023-12-11  35839.038802
# 2023-12-12  35828.647324

# %%
# plot a sample
prediction.plot(model.df_wide_numeric,
           series=model.df_wide_numeric.columns[0],
           start_date="2022-01-01")
# Out:
# <Axes: title={'center': 'Close with model BestN'}>
